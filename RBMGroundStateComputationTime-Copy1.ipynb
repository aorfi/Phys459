# %%
from qutip import *
import numpy as np
import scipy
import cmath
import matplotlib.pyplot as plt
plt.style.use('seaborn')
import itertools
from numpy.random import seed
from numpy.random import rand
from itertools import product
from scipy.misc import derivative
from scipy import optimize
from functools import wraps
from time import time

# %%
#Wrapper to time functions
def timing(f):
    @wraps(f)
    def wrap(*args, **kw):
        ti = time()
        result = f(*args, **kw)
        tf = time()
        t = tf-ti
        return result, t
    return wrap

# %%
#Make basis and get sz values
def operatorCreation(N):
    #operator definitionis
    si = qeye(2)
    sx = 0.5*sigmax()
    sy = 0.5*sigmay()
    sz = 0.5*sigmaz()

    sx_list = []
    sy_list = []
    sz_list = []
    

    for n in range(N):
        op_list = []
        for m in range(N):
            op_list.append(si)

        op_list[n] = sx
        sx_list.append(tensor(op_list))

        op_list[n] = sy
        sy_list.append(tensor(op_list))

        op_list[n] = sz
        sz_list.append(tensor(op_list))
        
        op_list[n] = si
    id = tensor(op_list)
        
    return sx_list, sy_list, sz_list,id

# %%
#Construct Hamiltonian
def hamiltonian(N,B,A0):
    sx_list = operatorCreation(N)[0]
    sy_list = operatorCreation(N)[1]
    sz_list = operatorCreation(N)[2]
    H = B*sz_list[0] 
    for n in range(N-1):
        H += A0*sz_list[0]*sz_list[n+1] + A0*sx_list[0]*sx_list[n+1] + A0*sy_list[0]*sy_list[n+1]
    return H

# %%
#Check if dengerate
def CheckDegenerate(H):
    estates = H.eigenstates()
    lowState = estates[0][0]
    secLowState = estates[0][1]
    if (abs(lowState-secLowState))<= 1e-10:
        return True
    else:
        return False

# %%
#Get Ground State Energy and Wavefuntion
class GroundState:
    
    def __init__(self, N, B, A0):
        self.hamiltonian = hamiltonian(N, B, A0)
     
    @timing
    def __call__(self):
        #find ground state
        H = self.hamiltonian
        groundState= H.groundstate()
        return groundState[0],groundState[1]

# %%
#Make basis and get sz values
def basisCreation(N):
    sz_list = operatorCreation(N)[2]
    Sbasis = []
    basisState = []
   
    for j in range(2):
        basisState.append(basis(2,j))
    b = itertools.product(basisState,repeat=N)
    basisTensor = list(b)
    #makes Sbasis the correct dimesion of Qobj
    for i in range(2**N):
        c = basisTensor[i][0]
        for j in range(N-1):
            c = tensor(c,basisTensor[i][j+1])
        Sbasis.append(c)

    
    #get sz values for basis states
    sz = np.zeros((2**N,N), dtype = complex)
    a = [[1 for j in range(N)] for i in range(2**N)]
    for i in range(2**N):
        for j in range(N):
            #matrix element <bra|Sz|ket>
            sz[i][j] = sz_list[j].matrix_element(Sbasis[i],Sbasis[i])
    return Sbasis, sz

# %%
#get randomized RBM parameters (between zero and 1)
def ranRBMpar(N,M):
    par = np.random.rand(2*(N+M+N*M))
    return par

# %%
#Function to give RBM wavefuntion
def RBM_ansatz(par,N, M):
    Sbasis = basisCreation(N)[0]
    sz = basisCreation(N)[1]
    #make parmeters complex
    num = N+M+N*M
    parC = np.vectorize(complex)(par[:num],par[num:])
    a = parC[:N]
    b = parC[N:N+M]
    W = parC[N+M:].reshape(M,N)
    expTerm = np.zeros(2**N, dtype = complex)
    coshTerm = np.zeros((M,2**N), dtype = complex)
    hidProduct = np.zeros(2**N, dtype = complex)
    psiMValues = np.zeros(2**N, dtype = complex)
    psiM = 0*Sbasis[0]

    for i in range(2**N):
        for m in range(M):
            coshTerm[m][i] = 2*np.cosh(np.dot(W[m],sz[i]) + b[m])
    hidProduct = np.prod(coshTerm, axis = 0) 
    
    for i in range(2**N):
        expTerm[i] = np.exp(np.dot(a,sz[i]))
        psiMValues[i] = expTerm[i]*hidProduct[i]
        psiM += psiMValues[i]*Sbasis[i]
    psiNorm = psiM.unit()
    return psiNorm

# %%
#Variation Energy Definition
def varEnergy(par,N, M, H):
    psiM = RBM_ansatz(par,N, M)
    E = expect(H,psiM)
    norm = psiM.norm()**2
    Enorm = E/norm
    return Enorm

# %%
#Energy Partials
def gradEnergy(par,N, M,H):
    eps = 0.001
    return optimize.approx_fprime(par,varEnergy,eps, N, M,H)

# %%
#Gradient Descent
class GradDescent:
    
    def __init__(self, N, B, A0):
        H = hamiltonian(N, B, A0)
        isDeg = CheckDegenerate(H)
        if (isDeg == True):
            raise ValueError("Hamiltonian has degenerate ground state")
        else:
            self.hamiltonian = H
     
    @timing 
    def __call__(self, N, M):
        par = ranRBMpar(N,M)
        H = self.hamiltonian
        min = scipy.optimize.fmin_cg(varEnergy,par,args= (N,M,H),gtol = 1e-04, full_output=True, retall = True, disp=True)
        #Ground State
        found_gs = RBM_ansatz(min[0],N, M)
        found_gs = found_gs.unit()
        #Ground State Energy
        found_gsEnergy =varEnergy(min[0], N, M,H)

        return min, found_gs, found_gsEnergy

# %%
#Error Calculation
def err(found_gs,gs,found_gsEnergy,gsEnergy):
    engErr = np.abs(found_gsEnergy-gsEnergy)
    waveFunctionErr = found_gs.dag()*gs
    waveFunctionErr = 1-waveFunctionErr.norm()
    
    return engErr,waveFunctionErr

# %% [markdown]
# ## Degeneracy Testing

# %%
N=3
M=1
B = 0
A0 = 1
gradDescent = GradDescent(N, B, A0)
gd = gradDescent(N, M)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-14-20df8be78a5c> in <module>
#       3 B = 0
#       4 A0 = 1
# ----> 5 gradDescent = GradDescent(N, B, A0)
#       6 gd = gradDescent(N, M)
#
# <ipython-input-12-b4e291ce36d1> in __init__(self, N, B, A0)
#       6         isDeg = CheckDegenerate(H)
#       7         if (isDeg == True):
# ----> 8             raise ValueError("Hamiltonian has degenerate ground state")
#       9         else:
#      10             self.hamiltonian = H
#
# ValueError: Hamiltonian has degenerate ground state

# %% [markdown]
# ## Energy Spectrum

# %%
N=2
A0 = 1
fullEng = []
engOrdered = []
BValues = np.arange(0,5,0.1)

for i in range(len(BValues)):
    H = hamiltonian(N, BValues[i], A0)
    estates = H.eigenstates()
    estatesEng = estates[0]
    fullEng.append(estatesEng)

#Makes list of ground state, second lowest state eg 
for i in range(len(fullEng[0])):
    engTemp = list(zip(*fullEng))[i]
    engOrdered.append(engTemp)

plt.figure(figsize=(8,8))
plt.title("Energy Spectrum N = 2, A0 = 1", size = 20)
plt.plot(BValues, fullEng)
plt.ylabel("Eigenstate Energy",size = 15)
plt.xlabel("B", size = 15)

plt.legend()
# Out:
# WARNING:matplotlib.legend:No handles with labels found to put in legend.

# %%
N=5
H = hamiltonian(N, np.pi, A0)
estates = H.eigenstates()
print(estates[0])
# Out:
# [-2.77707253 -2.44437902 -2.20327911 -2.20327911 -2.20327911 -2.05125038
#  -1.74816653 -1.74816653 -1.74816653 -1.57079633 -1.57079633 -1.54371813
#  -1.07079633 -1.07079633 -1.07079633 -0.57079633  1.04371813  1.24816653
#   1.24816653  1.24816653  1.55125038  1.57079633  1.57079633  1.70327911
#   1.70327911  1.70327911  1.94437902  2.07079633  2.07079633  2.07079633
#   2.27707253  2.57079633]

# %%
N=3
A0 = 1
fullEng = []
engOrdered = []
BValues = np.arange(0,5,0.1)

for i in range(len(BValues)):
    H = hamiltonian(N, BValues[i], A0)
    estates = H.eigenstates()
    estatesEng = estates[0]
    fullEng.append(estatesEng)

#Makes list of ground state, second lowest state eg 
for i in range(len(fullEng[0])):
    engTemp = list(zip(*fullEng))[i]
    engOrdered.append(engTemp)

plt.figure(figsize=(8,8))
plt.title("Energy Spectrum N = 3, A0 = 1", size = 20)
plt.plot(BValues, fullEng)
plt.ylabel("Eigenstate Energy",size = 15)
plt.xlabel("B", size = 15)

plt.legend()
# Out:
# WARNING:matplotlib.legend:No handles with labels found to put in legend.

# %%
N=4
A0 = 1
fullEng = []
engOrdered = []
BValues = np.arange(0,5,0.1)

for i in range(len(BValues)):
    H = hamiltonian(N, BValues[i], A0)
    estates = H.eigenstates()
    estatesEng = estates[0]
    fullEng.append(estatesEng)

#Makes list of ground state, second lowest state eg 
for i in range(len(fullEng[0])):
    engTemp = list(zip(*fullEng))[i]
    engOrdered.append(engTemp)

plt.figure(figsize=(8,8))
plt.title("Energy Spectrum N = 4, A0 = 1", size = 20)
plt.plot(BValues, fullEng)
plt.ylabel("Eigenstate Energy",size = 15)
plt.xlabel("B", size = 15)

plt.legend()
# Out:
# WARNING:matplotlib.legend:No handles with labels found to put in legend.

# %%
N=5
A0 = 1
fullEng = []
engOrdered = []
BValues = np.arange(0,5,0.1)

for i in range(5):
    H = hamiltonian(N, BValues[i], A0)
    estates = H.eigenstates()
    estatesEng = estates[0]
    fullEng.append(estatesEng)

#Makes list of ground state, second lowest state eg 
for i in range(len(fullEng[0])):
    engTemp = list(zip(*fullEng))[i]
    engOrdered.append(engTemp)

plt.figure(figsize=(8,8))
plt.title("Energy Spectrum N = 5, A0 = 1", size = 20)
plt.plot(BValues, fullEng)
plt.ylabel("Eigenstate Energy",size = 15)
plt.xlabel("B", size = 15)

plt.legend()
# Out:
# WARNING:matplotlib.legend:No handles with labels found to put in legend.

# %% [markdown]
# # Time and Error Comparion for N=2-4, M=1, B=1

# %%
#Parameter definition 
M_values = np.arange(1,5)
N=3
B = np.pi
A0 = 1
M1gdResults = [] #gives ground state estimation at each iteration of gd
M1gdState = []
M1gdTime = []

M1edState = []
M1edTime = []

M1ActualEng = []
M1engErr = []
M1stateErr = []

# %%
#vary N value
for i in range(M_values.size):
    #gradient descent
    gradDescent = GradDescent(N, B, A0)
    gd = gradDescent(N, M_values[i])
    M1gdResults.append(gd)
    M1gdState.append(gd[0])
    M1gdTime.append(gd[1])
    
    
    #exact diagonalization 
    groundState = GroundState(N,B,A0)
    ed = groundState()
    M1edState.append(ed[0])
    M1edTime.append(ed[1])
    
    #Error
    gdEng = gd[0][2]
    edEng = ed[0][0]
    M1ActualEng.append(edEng)
    gdState = gd[0][1]
    edState = ed[0][1]
    errTemp = err(gdState,edState,gdEng,edEng)
    M1engErr.append(errTemp[0])
    M1stateErr.append(errTemp[1])
# Out:
# Optimization terminated successfully.
#          Current function value: -2.070745
#          Iterations: 6
#          Function evaluations: 368
#          Gradient evaluations: 23
# Optimization terminated successfully.
#          Current function value: -2.070747
#          Iterations: 7
#          Function evaluations: 600
#          Gradient evaluations: 25
# Optimization terminated successfully.
#          Current function value: -2.203243
#          Iterations: 160
#          Function evaluations: 11904
#          Gradient evaluations: 372
# Optimization terminated successfully.
#          Current function value: -2.203262
#          Iterations: 163
#          Function evaluations: 13240
#          Gradient evaluations: 331

# %%
print('Gradient Descent Time: ', M1gdTime)
print('Exact Diagonalization Time: ', M1edTime)
print('Energy Error: ', M1engErr)
print('Wavefunction Error: ', M1stateErr)
# Out:
# Gradient Descent Time:  [2.703284978866577, 5.314201354980469, 108.93215417861938, 169.80508661270142]
# Exact Diagonalization Time:  [0.0010013580322265625, 0.0, 0.0009961128234863281, 0.0009970664978027344]
# Energy Error:  [0.13253421142451716, 0.1325323713485922, 3.604348580221739e-05, 1.719376641950987e-05]
# Wavefunction Error:  [0.01717585803978605, 0.01713899767322946, 1.7841809207941317e-05, 1.2042416521973465e-05]

# %%
plt.figure(figsize=(10,10))
ttl = plt.suptitle("N = 3, B = 1",size =20)
ttl.set_position([.5, 0.92])
ax1 = plt.subplot(2,1,1)

color = 'tab:red'
ax1.set_xlabel('M Value')
ax1.set_ylabel("Ground State Error $1-|<\Psi_{RBM}|\Psi_{ED}>|^2$", color=color)
ax1.plot(M_values, M1stateErr,color=color)
ax1.scatter(M_values, M1stateErr,color=color)
ax1.tick_params(axis='y', labelcolor=color)

ax2 = ax1.twinx()  

color = 'tab:blue'
ax2.set_ylabel('Energy Error $\Delta E = |E_{RBM}-E_{ED}|$', color=color)  
ax2.plot(M_values, M1engErr, color=color)
ax2.scatter(M_values, M1engErr, color=color)
ax2.tick_params(axis='y', labelcolor=color)

# %% [markdown]
# Individual Error vs Iteration

# %%
#N=2 groundstate error
N=2
parResults =M1gdResults[N-2][0][0][5]
numIter = len(parResults)
iter = np.arange(numIter)
state = []
eng = []
stateErr = []
engErr = []


gs = M1edState[N-2][1] 
gsEng = M1ActualEng[N-2]

#find state at each iteration
for i in range(numIter):
    stateIter = RBM_ansatz(parResults[i],N, M)
    state.append(stateIter)
    engIter = varEnergy(parResults[i],N, M, hamiltonian(N, B, A0))
    eng.append(engIter)
    errIter = err(stateIter,gs,engIter,gsEng)
    stateErr.append(errIter[1])
    engErr.append(errIter[0])
    


plt.figure(figsize=(10,10))
ttl = plt.suptitle("N = 2, M = 1, B = 1",size =20)
ttl.set_position([.5, 0.92])

ax1 = plt.subplot(2,1,1)
ax1.set_xlabel('Iteration')
ax1.set_ylabel('Wavefunction Error')
ax1.plot(iter, stateErr)

ax2 = plt.subplot(2,1,2)
ax2.set_xlabel('Iteration')
ax2.set_ylabel('Energy Error (Minimized by Gradient Descent)')
ax2.plot(iter, engErr)

# %%
#N=3 groundstate error
N=3
parResults =M1gdResults[N-2][0][0][5]
numIter = len(parResults)
iter = np.arange(numIter)
state = []
eng = []
stateErr = []
engErr = []


gs = M1edState[N-2][1] 
gsEng = M1ActualEng[N-2]

#find state at each iteration
for i in range(numIter):
    stateIter = RBM_ansatz(parResults[i],N, M)
    state.append(stateIter)
    engIter = varEnergy(parResults[i],N, M, hamiltonian(N, B, A0))
    eng.append(engIter)
    errIter = err(stateIter,gs,engIter,gsEng)
    stateErr.append(errIter[1])
    engErr.append(errIter[0])
    
plt.figure(figsize=(10,10))
ttl = plt.suptitle("N = 3, M = 1, B = 1",size =20)
ttl.set_position([.5, 0.92])

ax1 = plt.subplot(2,1,1)
ax1.set_xlabel('Iteration')
ax1.set_ylabel('Wavefunction Error')
ax1.plot(iter, stateErr)

ax2 = plt.subplot(2,1,2)
ax2.set_xlabel('Iteration')
ax2.set_ylabel('Energy Error (Minimized by Gradient Descent)')
ax2.plot(iter, engErr)

# %%
#N=4 groundstate error
N=4
parResults =M1gdResults[N-2][0][0][5]
numIter = len(parResults)
iter = np.arange(numIter)
state = []
eng = []
stateErr = []
engErr = []


gs = M1edState[N-2][1] 
gsEng = M1ActualEng[N-2]

#find state at each iteration
for i in range(numIter):
    stateIter = RBM_ansatz(parResults[i],N, M)
    state.append(stateIter)
    engIter = varEnergy(parResults[i],N, M, hamiltonian(N, B, A0))
    eng.append(engIter)
    errIter = err(stateIter,gs,engIter,gsEng)
    stateErr.append(errIter[1])
    engErr.append(errIter[0])
    
plt.figure(figsize=(10,10))
ttl = plt.suptitle("N = 4, M = 1, B = 1 ",size =20)
ttl.set_position([.5, 0.92])

ax1 = plt.subplot(2,1,1)
ax1.set_xlabel('Iteration')
ax1.set_ylabel('Wavefunction Error')
ax1.plot(iter, stateErr)

ax2 = plt.subplot(2,1,2)
ax2.set_xlabel('Iteration')
ax2.set_ylabel('Energy Error (Minimized by Gradient Descent)')
ax2.plot(iter, engErr)

# %%
#N=5 groundstate error
N=5
parResults =M1gdResults[N-2][0][0][5]
numIter = len(parResults)
iter = np.arange(numIter)
state = []
eng = []
stateErr = []
engErr = []


gs = M1edState[N-2][1] 
gsEng = M1ActualEng[N-2]

#find state at each iteration
for i in range(numIter):
    stateIter = RBM_ansatz(parResults[i],N, M)
    state.append(stateIter)
    engIter = varEnergy(parResults[i],N, M, hamiltonian(N, B, A0))
    eng.append(engIter)
    errIter = err(stateIter,gs,engIter,gsEng)
    stateErr.append(errIter[1])
    engErr.append(errIter[0])
    
plt.figure(figsize=(10,10))
ttl = plt.suptitle("N = 5, M = 2, B = 1 ",size =20)
ttl.set_position([.5, 0.92])

ax1 = plt.subplot(2,1,1)
ax1.set_xlabel('Iteration')
ax1.set_ylabel('Wavefunction Error')
ax1.plot(iter, stateErr)

ax2 = plt.subplot(2,1,2)
ax2.set_xlabel('Iteration')
ax2.set_ylabel('Energy Error (Minimized by Gradient Descent)')
ax2.plot(iter, engErr)

# %% [markdown]
# # Time and Error Comparion for N=2-4, M=2

# %%
#Parameter definition 
N_values = np.arange(2,6)
M=2
B = 1
A0 = 1
M2gdResults = [] #gives ground state estimation at each iteration of gd
M2gdState = []
M2gdTime = []

M2edState = []
M2edTime = []

M2ActualEng = []
M2engErr = []
M2stateErr = []

# %%
#vary N value
for i in range(N_values.size):
    #gradient descent
    gradDescent = GradDescent(N_values[i], B, A0)
    gd = gradDescent(N_values[i], M)
    M2gdResults.append(gd)
    M2gdState.append(gd[0])
    M2gdTime.append(gd[1])
    
    
    #exact diagonalization 
    groundState = GroundState(N_values[i],B,A0)
    ed = groundState()
    M2edState.append(ed[0])
    M2edTime.append(ed[1])
    
    #Error
    gdEng = gd[0][2]
    edEng = ed[0][0]
    M2ActualEng.append(edEng)
    gdState = gd[0][1]
    edState = ed[0][1]
    errTemp = err(gdState,edState,gdEng,edEng)
    M2engErr.append(errTemp[0])
    M2stateErr.append(errTemp[1])
# Out:
# Optimization terminated successfully.
#          Current function value: -0.957107
#          Iterations: 23
#          Function evaluations: 828
#          Gradient evaluations: 46
# Optimization terminated successfully.
#          Current function value: -1.280769
#          Iterations: 105
#          Function evaluations: 4248
#          Gradient evaluations: 177
# Optimization terminated successfully.
#          Current function value: -1.249932
#          Iterations: 9
#          Function evaluations: 990
#          Gradient evaluations: 33
# Optimization terminated successfully.
#          Current function value: -1.850643
#          Iterations: 946
#          Function evaluations: 71676
#          Gradient evaluations: 1991

# %%
print('Gradient Descent Time: ', M2gdTime)
print('Exact Diagonalization Time: ', M2edTime)
print('Energy Error: ', M2engErr)
print('Wavefunction Error: ', M2stateErr)
# Out:
# Gradient Descent Time:  [13.471232891082764, 102.36576104164124, 57.44014072418213, 6709.784581899643]
# Exact Diagonalization Time:  [0.0019147396087646484, 0.002100706100463867, 0.0010678768157958984, 0.0019168853759765625]
# Energy Error:  [1.186064024771838e-09, 7.685989891648148e-06, 0.32294385603276465, 0.00013782225985470298]
# Wavefunction Error:  [3.601302589473221e-10, 2.99098527889452e-06, 0.06309271510642223, 0.00028917659066485246]

# %%
plt.figure(figsize=(10,10))
ttl = plt.suptitle("M = 2",size =20)
ttl.set_position([.5, 0.92])
ax1 = plt.subplot(2,1,1)

color = 'tab:red'
ax1.set_xlabel('N Value')
ax1.set_ylabel('Wavefunction Error', color=color)
ax1.plot(N_values, M2stateErr,color=color)
ax1.scatter(N_values, M2stateErr,color=color)
ax1.tick_params(axis='y', labelcolor=color)

ax2 = ax1.twinx()  

color = 'tab:blue'
ax2.set_ylabel('Energy Error', color=color)  
ax2.plot(N_values, M2engErr, color=color)
ax2.scatter(N_values, M2engErr, color=color)
ax2.tick_params(axis='y', labelcolor=color)

ax3 = plt.subplot(2,1,2)

color = 'tab:red'
ax3.set_xlabel('N Value')
ax3.set_ylabel('Time (s)')
ax3.plot(N_values, M2gdTime,color=color)
ax3.scatter(N_values, M2gdTime,color=color, label = ' Gradient Descent')
color = 'tab:blue'
ax3.plot(N_values, M2edTime, color=color)
ax3.scatter(N_values, M2edTime, color=color, label = 'Exact Diagonalization')
ax3.legend()
plt.show()

# %%
#N=2 groundstate error
N=2
parResults =M2gdResults[N-2][0][0][5]
numIter = len(parResults)
iter = np.arange(numIter)
state = []
eng = []
stateErr = []
engErr = []


gs = M2edState[N-2][1] 
gsEng = M2ActualEng[N-2]

#find state at each iteration
for i in range(numIter):
    stateIter = RBM_ansatz(parResults[i],N, M)
    state.append(stateIter)
    engIter = varEnergy(parResults[i],N, M, hamiltonian(N, B, A0))
    eng.append(engIter)
    errIter = err(stateIter,gs,engIter,gsEng)
    stateErr.append(errIter[1])
    engErr.append(errIter[0])
    


plt.figure(figsize=(10,10))
ttl = plt.suptitle("N = 2, M = 2",size =20)
ttl.set_position([.5, 0.92])

ax1 = plt.subplot(2,1,1)
ax1.set_xlabel('Iteration')
ax1.set_ylabel('Wavefunction Error')
ax1.plot(iter, stateErr)

ax2 = plt.subplot(2,1,2)
ax2.set_xlabel('Iteration')
ax2.set_ylabel('Energy Error (Minimized by Gradient Descent)')
ax2.plot(iter, engErr)

# %%
#N=3 groundstate error
N=3
parResults =M2gdResults[N-2][0][0][5]
numIter = len(parResults)
iter = np.arange(numIter)
state = []
eng = []
stateErr = []
engErr = []


gs = M2edState[N-2][1] 
gsEng = M2ActualEng[N-2]

#find state at each iteration
for i in range(numIter):
    stateIter = RBM_ansatz(parResults[i],N, M)
    state.append(stateIter)
    engIter = varEnergy(parResults[i],N, M, hamiltonian(N, B, A0))
    eng.append(engIter)
    errIter = err(stateIter,gs,engIter,gsEng)
    stateErr.append(errIter[1])
    engErr.append(errIter[0])
    
plt.figure(figsize=(10,10))
ttl = plt.suptitle("N = 3, M = 2",size =20)
ttl.set_position([.5, 0.92])

ax1 = plt.subplot(2,1,1)
ax1.set_xlabel('Iteration')
ax1.set_ylabel('Wavefunction Error')
ax1.plot(iter, stateErr)

ax2 = plt.subplot(2,1,2)
ax2.set_xlabel('Iteration')
ax2.set_ylabel('Energy Error (Minimized by Gradient Descent)')
ax2.plot(iter, engErr)

# %%
#N=4 groundstate error
N=4
parResults =M2gdResults[N-2][0][0][5]
numIter = len(parResults)
iter = np.arange(numIter)
state = []
eng = []
stateErr = []
engErr = []


gs = M2edState[N-2][1] 
gsEng = M2ActualEng[N-2]

#find state at each iteration
for i in range(numIter):
    stateIter = RBM_ansatz(parResults[i],N, M)
    state.append(stateIter)
    engIter = varEnergy(parResults[i],N, M, hamiltonian(N, B, A0))
    eng.append(engIter)
    errIter = err(stateIter,gs,engIter,gsEng)
    stateErr.append(errIter[1])
    engErr.append(errIter[0])
    
plt.figure(figsize=(10,10))
ttl = plt.suptitle("N = 4, M = 2",size =20)
ttl.set_position([.5, 0.92])

ax1 = plt.subplot(2,1,1)
ax1.set_xlabel('Iteration')
ax1.set_ylabel('Wavefunction Error')
ax1.plot(iter, stateErr)

ax2 = plt.subplot(2,1,2)
ax2.set_xlabel('Iteration')
ax2.set_ylabel('Energy Error (Minimized by Gradient Descent)')
ax2.plot(iter, engErr)

# %%
#N=5 groundstate error
N=5
parResults =M2gdResults[N-2][0][0][5]
numIter = len(parResults)
iter = np.arange(numIter)
state = []
eng = []
stateErr = []
engErr = []


gs = M2edState[N-2][1] 
gsEng = M2ActualEng[N-2]

#find state at each iteration
for i in range(numIter):
    stateIter = RBM_ansatz(parResults[i],N, M)
    state.append(stateIter)
    engIter = varEnergy(parResults[i],N, M, hamiltonian(N, B, A0))
    eng.append(engIter)
    errIter = err(stateIter,gs,engIter,gsEng)
    stateErr.append(errIter[1])
    engErr.append(errIter[0])
    
plt.figure(figsize=(10,10))
ttl = plt.suptitle("N = 5, M = 2",size =20)
ttl.set_position([.5, 0.92])

ax1 = plt.subplot(2,1,1)
ax1.set_xlabel('Iteration')
ax1.set_ylabel('Wavefunction Error')
ax1.plot(iter, stateErr)

ax2 = plt.subplot(2,1,2)
ax2.set_xlabel('Iteration')
ax2.set_ylabel('Energy Error (Minimized by Gradient Descent)')
ax2.plot(iter, engErr)

# %% [markdown]
# # Time and Error Comparion for N=2-4, M=3

# %%
#Parameter definition 
N_values = np.arange(2,6)
M=3
B = 1
A0 = 1
M3gdResults = [] #gives ground state estimation at each iteration of gd
M3gdState = []
M3gdTime = []

M3edState = []
M3edTime = []

M3ActualEng = []
M3engErr = []
M3stateErr = []

# %%
#vary N value
for i in range(N_values.size):
    #gradient descent
    gradDescent = GradDescent(N_values[i], B, A0)
    gd = gradDescent(N_values[i], M)
    M3gdResults.append(gd)
    M3gdState.append(gd[0])
    M3gdTime.append(gd[1])
    
    
    #exact diagonalization 
    groundState = GroundState(N_values[i],B,A0)
    ed = groundState()
    M3edState.append(ed[0])
    M3edTime.append(ed[1])
    
    #Error
    gdEng = gd[0][2]
    edEng = ed[0][0]
    M3ActualEng.append(edEng)
    gdState = gd[0][1]
    edState = ed[0][1]
    errTemp = err(gdState,edState,gdEng,edEng)
    M3engErr.append(errTemp[0])
    M3stateErr.append(errTemp[1])
# Out:
# Optimization terminated successfully.
#          Current function value: -0.957083
#          Iterations: 45
#          Function evaluations: 2136
#          Gradient evaluations: 89
# Optimization terminated successfully.
#          Current function value: -0.499965
#          Iterations: 5
#          Function evaluations: 608
#          Gradient evaluations: 19
# Optimization terminated successfully.
#          Current function value: -1.368000
#          Iterations: 27
#          Function evaluations: 2880
#          Gradient evaluations: 72
# Optimization terminated successfully.
#          Current function value: -1.499987
#          Iterations: 8
#          Function evaluations: 1680
#          Gradient evaluations: 35

# %%
print('Gradient Descent Time: ', M3gdTime)
print('Exact Diagonalization Time: ', M3edTime)
print('Energy Error: ', M3engErr)
print('Wavefunction Error: ', M3stateErr)
# Out:
# Gradient Descent Time:  [30.36620569229126, 17.61361527442932, 142.90079307556152, 160.52170133590698]
# Exact Diagonalization Time:  [0.002027273178100586, 0.001028299331665039, 0.0020470619201660156, 0.002033233642578125]
# Energy Error:  [2.389184406981215e-05, 0.7808111911326991, 0.20487548918183318, 0.35079430675626266]
# Wavefunction Error:  [1.666852465465052e-05, 0.9984627280952023, 0.04174044230895202, 0.05646988563673183]

# %%
plt.figure(figsize=(10,10))
ttl = plt.suptitle("M = 3",size =20)
ttl.set_position([.5, 0.92])
ax1 = plt.subplot(2,1,1)

color = 'tab:red'
ax1.set_xlabel('N Value')
ax1.set_ylabel('Wavefunction Error', color=color)
ax1.plot(N_values, M3stateErr,color=color)
ax1.scatter(N_values, M3stateErr,color=color)
ax1.tick_params(axis='y', labelcolor=color)

ax2 = ax1.twinx()  

color = 'tab:blue'
ax2.set_ylabel('Energy Error', color=color)  
ax2.plot(N_values, M3engErr, color=color)
ax2.scatter(N_values, M3engErr, color=color)
ax2.tick_params(axis='y', labelcolor=color)

ax3 = plt.subplot(2,1,2)

color = 'tab:red'
ax3.set_xlabel('N Value')
ax3.set_ylabel('Time (s)')
ax3.plot(N_values, M3gdTime,color=color)
ax3.scatter(N_values, M3gdTime,color=color, label = ' Gradient Descent')
color = 'tab:blue'
ax3.plot(N_values, M3edTime, color=color)
ax3.scatter(N_values, M3edTime, color=color, label = 'Exact Diagonalization')
ax3.legend()
plt.show()

# %%
#N=2 groundstate error
N=2
parResults =M3gdResults[N-2][0][0][5]
numIter = len(parResults)
iter = np.arange(numIter)
state = []
eng = []
stateErr = []
engErr = []


gs = M3edState[N-2][1] 
gsEng = M3ActualEng[N-2]

#find state at each iteration
for i in range(numIter):
    stateIter = RBM_ansatz(parResults[i],N, M)
    state.append(stateIter)
    engIter = varEnergy(parResults[i],N, M, hamiltonian(N, B, A0))
    eng.append(engIter)
    errIter = err(stateIter,gs,engIter,gsEng)
    stateErr.append(errIter[1])
    engErr.append(errIter[0])
    


plt.figure(figsize=(10,10))
ttl = plt.suptitle("N = 2, M = 3",size =20)
ttl.set_position([.5, 0.92])

ax1 = plt.subplot(2,1,1)
ax1.set_xlabel('Iteration')
ax1.set_ylabel('Wavefunction Error')
ax1.plot(iter, stateErr)

ax2 = plt.subplot(2,1,2)
ax2.set_xlabel('Iteration')
ax2.set_ylabel('Energy Error (Minimized by Gradient Descent)')
ax2.plot(iter, engErr)

# %%
print(M3gdResults[0][0][0][5])
# Out:
# [array([0.10139669, 0.26958123, 0.66019068, 0.366438  , 0.97943456,
#        0.69860023, 0.60598282, 0.92647252, 0.65107493, 0.42765553,
#        0.89067231, 0.07257511, 0.76404547, 0.99259896, 0.15079899,
#        0.63416174, 0.31854249, 0.06276581, 0.81677022, 0.49677906,
#        0.92203735, 0.11997428]), array([-1.73230383,  0.30122492,  0.17446471, -1.01816385,  0.57934193,
#        -1.04052749,  0.4991005 , -0.08497093,  0.07412444, -1.25329676,
#         0.77479571,  0.19857056,  0.6380507 ,  0.17599402,  0.62955596,
#         0.71471638,  1.15315352, -0.44896348,  1.01160398,  0.5749567 ,
#         1.19939393, -0.04594507]), array([-1.92742075,  0.73734474,  0.19330962, -1.21071037,  0.47016282,
#        -1.38254506,  0.81088423, -0.25357599, -0.31957994, -1.57577395,
#         1.18517052,  0.15264858,  0.68397276,  0.2104918 ,  0.583375  ,
#         0.90004235,  1.23051927, -0.41439401,  1.14291592,  0.51014476,
#         1.23562521, -0.09856302]), array([-1.65461044,  0.70238826, -0.36522729, -1.3277881 , -0.26777347,
#        -1.538424  ,  1.0433825 , -0.58428595, -0.26032437, -1.7634394 ,
#         0.92480134, -0.44321933]), array([-1.23732168,  0.86648419, -0.30889219, -1.41722135, -0.01039422,
#        -2.08824808,  1.61042501, -0.94198298, -0.28818584, -2.1607878 ,
#         2.23704722,  0.15393887,  0.68267982, -0.31118738,  0.24570397,
#         1.34971139,  1.43556959,  0.0353994 ,  1.20578088,  0.66455844,
#         0.91658228, -0.45172935]), array([-1.23698181,  0.86632884, -0.3092766 , -1.41724591, -0.01079513,
#        -2.08839433,  1.61054173, -0.94227707, -0.28803865, -2.16089232,
#         2.23719499,  0.15435909,  0.68225958, -0.31228012,  0.24554503,
#         1.34904294,  1.43570549,  0.03551532,  1.20543386,  0.66497002,
#         0.91639628, -0.45191124]), array([-1.23706554,  0.866632  , -0.30878056, -1.41722183, -0.01225801,
#        -2.08858998,  1.61069728, -0.94221343, -0.28827918, -2.16206301,
#         2.23637171,  0.1541823 ,  0.68243638, -0.3123369 ,  0.24548179,
#         1.34918645,  1.43592835,  0.03578032,  1.20563892,  0.66486541,
#         0.91574851, -0.45257117]), array([-1.23833749,  0.86900718, -0.30452972, -1.41693151, -0.01791176,
#        -2.08960854,  1.61151282, -0.94113415, -0.29024862, -2.16793088,
#         2.23222407,  0.15369691,  0.68292177, -0.31334965,  0.2451468 ,
#         1.34906007,  1.43703134,  0.03712907,  1.20633136,  0.66467725,
#         0.91248823, -0.4558883 ]), array([-1.24023087,  0.87314796, -0.29731178, -1.41647462, -0.03065155,
#        -2.09164826,  1.61313683, -0.93955662, -0.29364112, -2.17979889,
#         2.2238594 ,  0.15246023,  0.68415843, -0.31497715,  0.24446731,
#         1.34937348,  1.43928822,  0.03985318,  1.20794503,  0.66408803,
#         0.90588076, -0.46261258]), array([-1.24009105,  0.87301926, -0.29758627, -1.41650165, -0.03088588,
#        -2.09164946,  1.61313549, -0.93968181, -0.29352547, -2.17979334,
#         2.22387978,  0.15239353,  0.68422513, -0.31487555,  0.24446609,
#         1.34953613,  1.43930031,  0.03986095,  1.208003  ,  0.66403412,
#         0.90586895, -0.46262512])]

# %%
#N=3 groundstate error
N=3
parResults =M3gdResults[N-2][0][0][5]
numIter = len(parResults)
iter = np.arange(numIter)
state = []
eng = []
stateErr = []
engErr = []


gs = M3edState[N-2][1] 
gsEng = M3ActualEng[N-2]

#find state at each iteration
for i in range(numIter):
    stateIter = RBM_ansatz(parResults[i],N, M)
    state.append(stateIter)
    engIter = varEnergy(parResults[i],N, M, hamiltonian(N, B, A0))
    eng.append(engIter)
    errIter = err(stateIter,gs,engIter,gsEng)
    stateErr.append(errIter[1])
    engErr.append(errIter[0])
    


plt.figure(figsize=(10,10))
ttl = plt.suptitle("N = 3, M = 3",size =20)
ttl.set_position([.5, 0.92])

ax1 = plt.subplot(2,1,1)
ax1.set_xlabel('Iteration')
ax1.set_ylabel('Wavefunction Error')
ax1.plot(iter, stateErr)

ax2 = plt.subplot(2,1,2)
ax2.set_xlabel('Iteration')
ax2.set_ylabel('Energy Error (Minimized by Gradient Descent)')
ax2.plot(iter, engErr)

# %%
#N=4 groundstate error
N=4
parResults =M3gdResults[N-2][0][0][5]
numIter = len(parResults)
iter = np.arange(numIter)
state = []
eng = []
stateErr = []
engErr = []


gs = M3edState[N-2][1] 
gsEng = M3ActualEng[N-2]

#find state at each iteration
for i in range(numIter):
    stateIter = RBM_ansatz(parResults[i],N, M)
    state.append(stateIter)
    engIter = varEnergy(parResults[i],N, M, hamiltonian(N, B, A0))
    eng.append(engIter)
    errIter = err(stateIter,gs,engIter,gsEng)
    stateErr.append(errIter[1])
    engErr.append(errIter[0])
    


plt.figure(figsize=(10,10))
ttl = plt.suptitle("N = 4, M = 3",size =20)
ttl.set_position([.5, 0.92])

ax1 = plt.subplot(2,1,1)
ax1.set_xlabel('Iteration')
ax1.set_ylabel('Wavefunction Error')
ax1.plot(iter, stateErr)

ax2 = plt.subplot(2,1,2)
ax2.set_xlabel('Iteration')
ax2.set_ylabel('Energy Error (Minimized by Gradient Descent)')
ax2.plot(iter, engErr)

# %%
#N=5 groundstate error
N=5
parResults =M3gdResults[N-2][0][0][5]
numIter = len(parResults)
iter = np.arange(numIter)
state = []
eng = []
stateErr = []
engErr = []


gs = M3edState[N-2][1] 
gsEng = M3ActualEng[N-2]

#find state at each iteration
for i in range(numIter):
    stateIter = RBM_ansatz(parResults[i],N, M)
    state.append(stateIter)
    engIter = varEnergy(parResults[i],N, M, hamiltonian(N, B, A0))
    eng.append(engIter)
    errIter = err(stateIter,gs,engIter,gsEng)
    stateErr.append(errIter[1])
    engErr.append(errIter[0])
    


plt.figure(figsize=(10,10))
ttl = plt.suptitle("N = 5, M = 3",size =20)
ttl.set_position([.5, 0.92])

ax1 = plt.subplot(2,1,1)
ax1.set_xlabel('Iteration')
ax1.set_ylabel('Wavefunction Error')
ax1.plot(iter, stateErr)

ax2 = plt.subplot(2,1,2)
ax2.set_xlabel('Iteration')
ax2.set_ylabel('Energy Error (Minimized by Gradient Descent)')
ax2.plot(iter, engErr)

# %% [markdown]
# # Time and Error Comparion for N=2-4, M=4

# %%
#Parameter definition 
N_values = np.arange(2,6)
M=4
B = 1
A0 = 1
M4gdResults = [] #gives ground state estimation at each iteration of gd
M4gdState = []
M4gdTime = []

M4edState = []
M4edTime = []

M4ActualEng = []
M4engErr = []
M4stateErr = []

# %%
#vary N value
for i in range(N_values.size):
    #gradient descent
    gradDescent = GradDescent(N_values[i], B, A0)
    gd = gradDescent(N_values[i], M)
    M4gdResults.append(gd)
    M4gdState.append(gd[0])
    M4gdTime.append(gd[1])
    
    
    #exact diagonalization 
    groundState = GroundState(N_values[i],B,A0)
    ed = groundState()
    M4edState.append(ed[0])
    M4edTime.append(ed[1])
    
    #Error
    gdEng = gd[0][2]
    edEng = ed[0][0]
    M4ActualEng.append(edEng)
    gdState = gd[0][1]
    edState = ed[0][1]
    errTemp = err(gdState,edState,gdEng,edEng)
    M4engErr.append(errTemp[0])
    M4stateErr.append(errTemp[1])
# Out:
# Optimization terminated successfully.
#          Current function value: -0.957107
#          Iterations: 23
#          Function evaluations: 1320
#          Gradient evaluations: 44
# Optimization terminated successfully.
#          Current function value: -1.280753
#          Iterations: 224
#          Function evaluations: 20320
#          Gradient evaluations: 508
# Optimization terminated successfully.
#          Current function value: -1.367994
#          Iterations: 86
#          Function evaluations: 9650
#          Gradient evaluations: 193
# Optimization terminated successfully.
#          Current function value: -1.850659
#          Iterations: 225
#          Function evaluations: 30840
#          Gradient evaluations: 514

# %%
print('Gradient Descent Time: ', M4gdTime)
print('Exact Diagonalization Time: ', M4edTime)
print('Energy Error: ', M4engErr)
print('Wavefunction Error: ', M4stateErr)
# Out:
# Gradient Descent Time:  [6.247454404830933, 232.55639338493347, 183.3818347454071, 1462.973614692688]
# Exact Diagonalization Time:  [0.0, 0.0010356903076171875, 0.000995635986328125, 0.0010018348693847656]
# Energy Error:  [1.615335198934531e-09, 2.371847120996584e-05, 0.2048818043014793, 0.00012165728306512413]
# Wavefunction Error:  [5.046926210283686e-10, 3.532258488536666e-05, 0.041747555022077054, 0.0002832868080266948]

# %%
plt.figure(figsize=(10,10))
ttl = plt.suptitle("M = 3",size =20)
ttl.set_position([.5, 0.92])
ax1 = plt.subplot(2,1,1)

color = 'tab:red'
ax1.set_xlabel('N Value')
ax1.set_ylabel('Wavefunction Error', color=color)
ax1.plot(N_values, M4stateErr,color=color)
ax1.scatter(N_values, M4stateErr,color=color)
ax1.tick_params(axis='y', labelcolor=color)

ax2 = ax1.twinx()  

color = 'tab:blue'
ax2.set_ylabel('Energy Error', color=color)  
ax2.plot(N_values, M4engErr, color=color)
ax2.scatter(N_values, M4engErr, color=color)
ax2.tick_params(axis='y', labelcolor=color)

ax3 = plt.subplot(2,1,2)

color = 'tab:red'
ax3.set_xlabel('N Value')
ax3.set_ylabel('Time (s)')
ax3.plot(N_values, M4gdTime,color=color)
ax3.scatter(N_values, M4gdTime,color=color, label = ' Gradient Descent')
color = 'tab:blue'
ax3.plot(N_values, M4edTime, color=color)
ax3.scatter(N_values, M4edTime, color=color, label = 'Exact Diagonalization')
ax3.legend()
plt.show()

# %%
#N=2 groundstate error
N=2
parResults =M4gdResults[N-2][0][0][5]
numIter = len(parResults)
iter = np.arange(numIter)
state = []
eng = []
stateErr = []
engErr = []


gs = M4edState[N-2][1] 
gsEng = M4ActualEng[N-2]

#find state at each iteration
for i in range(numIter):
    stateIter = RBM_ansatz(parResults[i],N, M)
    state.append(stateIter)
    engIter = varEnergy(parResults[i],N, M, hamiltonian(N, B, A0))
    eng.append(engIter)
    errIter = err(stateIter,gs,engIter,gsEng)
    stateErr.append(errIter[1])
    engErr.append(errIter[0])
    


plt.figure(figsize=(10,10))
ttl = plt.suptitle("N = 2, M = 3",size =20)
ttl.set_position([.5, 0.92])

ax1 = plt.subplot(2,1,1)
ax1.set_xlabel('Iteration')
ax1.set_ylabel('Wavefunction Error')
ax1.plot(iter, stateErr)

ax2 = plt.subplot(2,1,2)
ax2.set_xlabel('Iteration')
ax2.set_ylabel('Energy Error (Minimized by Gradient Descent)')
ax2.plot(iter, engErr)

# %%
#N=3 groundstate error
N=3
parResults =M4gdResults[N-2][0][0][5]
numIter = len(parResults)
iter = np.arange(numIter)
state = []
eng = []
stateErr = []
engErr = []


gs = M4edState[N-2][1] 
gsEng = M4ActualEng[N-2]

#find state at each iteration
for i in range(numIter):
    stateIter = RBM_ansatz(parResults[i],N, M)
    state.append(stateIter)
    engIter = varEnergy(parResults[i],N, M, hamiltonian(N, B, A0))
    eng.append(engIter)
    errIter = err(stateIter,gs,engIter,gsEng)
    stateErr.append(errIter[1])
    engErr.append(errIter[0])
    


plt.figure(figsize=(10,10))
ttl = plt.suptitle("N = 3, M = 3",size =20)
ttl.set_position([.5, 0.92])

ax1 = plt.subplot(2,1,1)
ax1.set_xlabel('Iteration')
ax1.set_ylabel('Wavefunction Error')
ax1.plot(iter, stateErr)

ax2 = plt.subplot(2,1,2)
ax2.set_xlabel('Iteration')
ax2.set_ylabel('Energy Error (Minimized by Gradient Descent)')
ax2.plot(iter, engErr)

# %%
#N=4 groundstate error
N=4
parResults =M4gdResults[N-2][0][0][5]
numIter = len(parResults)
iter = np.arange(numIter)
state = []
eng = []
stateErr = []
engErr = []


gs = M4edState[N-2][1] 
gsEng = M4ActualEng[N-2]

#find state at each iteration
for i in range(numIter):
    stateIter = RBM_ansatz(parResults[i],N, M)
    state.append(stateIter)
    engIter = varEnergy(parResults[i],N, M, hamiltonian(N, B, A0))
    eng.append(engIter)
    errIter = err(stateIter,gs,engIter,gsEng)
    stateErr.append(errIter[1])
    engErr.append(errIter[0])
    


plt.figure(figsize=(10,10))
ttl = plt.suptitle("N = 4, M = 3",size =20)
ttl.set_position([.5, 0.92])

ax1 = plt.subplot(2,1,1)
ax1.set_xlabel('Iteration')
ax1.set_ylabel('Wavefunction Error')
ax1.plot(iter, stateErr)

ax2 = plt.subplot(2,1,2)
ax2.set_xlabel('Iteration')
ax2.set_ylabel('Energy Error (Minimized by Gradient Descent)')
ax2.plot(iter, engErr)

# %%
#N=5 groundstate error
N=5
parResults =M4gdResults[N-2][0][0][5]
numIter = len(parResults)
iter = np.arange(numIter)
state = []
eng = []
stateErr = []
engErr = []


gs = M4edState[N-2][1] 
gsEng = M4ActualEng[N-2]

#find state at each iteration
for i in range(numIter):
    stateIter = RBM_ansatz(parResults[i],N, M)
    state.append(stateIter)
    engIter = varEnergy(parResults[i],N, M, hamiltonian(N, B, A0))
    eng.append(engIter)
    errIter = err(stateIter,gs,engIter,gsEng)
    stateErr.append(errIter[1])
    engErr.append(errIter[0])
    


plt.figure(figsize=(10,10))
ttl = plt.suptitle("N = 5, M = 3",size =20)
ttl.set_position([.5, 0.92])

ax1 = plt.subplot(2,1,1)
ax1.set_xlabel('Iteration')
ax1.set_ylabel('Wavefunction Error')
ax1.plot(iter, stateErr)

ax2 = plt.subplot(2,1,2)
ax2.set_xlabel('Iteration')
ax2.set_ylabel('Energy Error (Minimized by Gradient Descent)')
ax2.plot(iter, engErr)
