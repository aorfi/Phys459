# %%
import json
from qutip import *
import numpy as np
import scipy
import cmath
import matplotlib.pyplot as plt
plt.style.use('seaborn')
import itertools
from numpy.random import seed
from numpy.random import rand
from itertools import product
from scipy.misc import derivative
from scipy import optimize
from functools import wraps
from time import time
from scipy.optimize import minimize
from matplotlib import gridspec

# %%
#Wrapper to time functions
def timing(f):
    @wraps(f)
    def wrap(*args, **kw):
        ti = time()
        result = f(*args, **kw)
        tf = time()
        t = tf-ti
        return result, t
    return wrap

# %%
#Make basis and get sz values
def operatorCreation(N):
    #operator definitionis
    si = qeye(2)
    sx = 0.5*sigmax()
    sy = 0.5*sigmay()
    sz = 0.5*sigmaz()

    sx_list = []
    sy_list = []
    sz_list = []
    

    for n in range(N):
        op_list = []
        for m in range(N):
            op_list.append(si)

        op_list[n] = sx
        sx_list.append(tensor(op_list))

        op_list[n] = sy
        sy_list.append(tensor(op_list))

        op_list[n] = sz
        sz_list.append(tensor(op_list))
        
        op_list[n] = si
    id = tensor(op_list)
        
    return sx_list, sy_list, sz_list,id

# %%
#Construct Hamiltonian
def hamiltonian(N,B,A0):
    sx_list = operatorCreation(N)[0]
    sy_list = operatorCreation(N)[1]
    sz_list = operatorCreation(N)[2]
    H = B*sz_list[0] 
    for n in range(N-1):
        H += A0*sz_list[0]*sz_list[n+1] + A0*sx_list[0]*sx_list[n+1] + A0*sy_list[0]*sy_list[n+1]
    return H

# %%
#Check if dengerate
def CheckDegenerate(H):
    estates = H.eigenstates()
    lowState = estates[0][0]
    secLowState = estates[0][1]
    if (abs(lowState-secLowState))<= 1e-10:
        return True
    else:
        return False

# %%
#Get Ground State Energy and Wavefuntion
class GroundState:
    
    def __init__(self, N, B, A0):
        self.hamiltonian = hamiltonian(N, B, A0)
     
    @timing
    def __call__(self):
        #find ground state
        H = self.hamiltonian
        groundState= H.groundstate()
        return groundState[0],groundState[1]

# %%
#Make basis and get sz values
def basisCreation(N):
    sz_list = operatorCreation(N)[2]
    Sbasis = []
    basisState = []
   
    for j in range(2):
        basisState.append(basis(2,j))
    b = itertools.product(basisState,repeat=N)
    basisTensor = list(b)
    #makes Sbasis the correct dimesion of Qobj
    for i in range(2**N):
        c = basisTensor[i][0]
        for j in range(N-1):
            c = tensor(c,basisTensor[i][j+1])
        Sbasis.append(c)

    
    #get sz values for basis states
    sz = np.zeros((2**N,N), dtype = complex)
    a = [[1 for j in range(N)] for i in range(2**N)]
    for i in range(2**N):
        for j in range(N):
            #matrix element <bra|Sz|ket>
            sz[i][j] = sz_list[j].matrix_element(Sbasis[i],Sbasis[i])
    return Sbasis, sz

# %%
#get randomized RBM parameters (between zero and 1)
def ranRBMpar(N,M):
    par = 1-2*np.random.rand(2*(N+M+N*M))
    return par

# %%
#Function to give RBM wavefuntion
def RBM_ansatz(par,N, M):
    Sbasis = basisCreation(N)[0]
    sz = basisCreation(N)[1]
    #make parmeters complex
    num = N+M+N*M
    parC = np.vectorize(complex)(par[:num],par[num:])
    a = parC[:N]
    b = parC[N:N+M]
    W = parC[N+M:].reshape(M,N)
    expTerm = np.zeros(2**N, dtype = complex)
    coshTerm = np.zeros((M,2**N), dtype = complex)
    hidProduct = np.zeros(2**N, dtype = complex)
    psiMValues = np.zeros(2**N, dtype = complex)
    psiM = 0*Sbasis[0]

    for i in range(2**N):
        for m in range(M):
            coshTerm[m][i] = 2*np.cosh(np.dot(W[m],sz[i]) + b[m])
    hidProduct = np.prod(coshTerm, axis = 0) 
    
    for i in range(2**N):
        expTerm[i] = np.exp(np.dot(a,sz[i]))
        psiMValues[i] = expTerm[i]*hidProduct[i]
        psiM += psiMValues[i]*Sbasis[i]
    psiNorm = psiM.unit()
    return psiNorm

# %%
#Variation Energy Definition
def varEnergy(par,N, M, H):
    psiM = RBM_ansatz(par,N, M)
    E = expect(H,psiM)
    norm = psiM.norm()**2
    Enorm = E/norm
    return Enorm

# %%
#Energy Partials
def gradEnergy(par,N, M,H):
    eps = 0.001
    return optimize.approx_fprime(par,varEnergy,eps, N, M,H)

# %%
#Conjugate Gradient Descent
class ConGradDescent:
    
    def __init__(self, N, B, A0):
        H = hamiltonian(N, B, A0)
        isDeg = CheckDegenerate(H)
        if (isDeg == True):
            raise ValueError("Hamiltonian has degenerate ground state")
        else:
            self.hamiltonian = H
     
    @timing 
    def __call__(self, N, M,par):
        H = self.hamiltonian
        min = scipy.optimize.fmin_cg(varEnergy,par,args= (N,M,H),gtol = 1e-04, full_output=True, retall = True, disp=True)
        #Ground State
        found_gs = RBM_ansatz(min[0],N, M)
        found_gs = found_gs.unit()
        #Ground State Energy
        found_gsEnergy =varEnergy(min[0], N, M,H)
        return min, found_gs, found_gsEnergy

# %%
#Error Calculation
def err(found_gs,gs,found_gsEnergy,gsEnergy):
    engErr = np.abs(found_gsEnergy-gsEnergy)
    waveFunctionErr = found_gs.dag()*gs
    waveFunctionErr = 1-waveFunctionErr.norm()
    
    return engErr,waveFunctionErr

# %%
#Ensures conjugate gradient descent convergance
def CgdConvergance(N, M, B, A0):
    #random parameters
    par = ranRBMpar(N,M)
    #performs conjugate gradient descent
    conGradDescent = ConGradDescent(N, B, A0)
    cgd = conGradDescent(N, M,par)
    #get actual ground state
    groundState = GroundState(N,B,A0)
    ed = groundState()
    #Calculate Error
    error = err(cgd[0][1],ed[0][1],cgd[0][2],ed[0][0])
    relativeErr = np.abs(error[0]/ed[0][0])
    print('relativeErr',relativeErr)
    #Run again if the relative error is larger than 0.01
    runs = 1
    while(relativeErr>0.01):
        par = ranRBMpar(N,M)
        cgd = conGradDescent(N, M,par)
        error = err(cgd[0][1],ed[0][1],cgd[0][2],ed[0][0])
        relativeErr = np.abs(error[0]/ed[0][0])
        runs += 1
        print('relativeErr in Loop',relativeErr)
    return cgd, error, runs

# %% [markdown]
# ## Other Minimization Testing

# %%
N=2
M=1
B = 1
A0 = 1

# %%
#Parameter definition 
N= 2
M=1
B = 1
A0 = 1

cgdResults = [] #gives ground state estimation at each iteration of gd
cgdState = []
cgdTime = []
cgdEngErr = []
cgdStateErr = []

edState = []
edTime = []
ActualEng = []

hisIt = np.arange(500)

# %%
for i in range(len(hisIt)):
    par = ranRBMpar(N,M)
    
    #gradient descent
    conGradDescent = ConGradDescent(N, B, A0)
    cgd = conGradDescent(N,M,par)
    cgdResults.append(cgd)
    cgdState.append(cgd[0])
    cgdTime.append(cgd[1])
    
    
    #exact diagonalization 
    groundState = GroundState(N,B,A0)
    ed = groundState()
    edState.append(ed[0])
    edTime.append(ed[1])
    
    
    #Error
    cgdEngTemp = cgd[0][2]
    edEngTemp = ed[0][0]
    
    ActualEng.append(edEngTemp)
    cgdStateTemp = cgd[0][1]
    edStateTemp = ed[0][1]

    
    cgdErrTemp = err(cgdStateTemp,edStateTemp,cgdEngTemp,edEngTemp)  
    cgdEngErr.append(cgdErrTemp[0])
    cgdStateErr.append(cgdErrTemp[1])
# Out:
# Optimization terminated successfully.
#          Current function value: -0.749999
#          Iterations: 5
#          Function evaluations: 252
#          Gradient evaluations: 21
# Optimization terminated successfully.
#          Current function value: -0.957107
#          Iterations: 33
#          Function evaluations: 768
#          Gradient evaluations: 64
# Optimization terminated successfully.
#          Current function value: -0.957089
#          Iterations: 35
#          Function evaluations: 888
#          Gradient evaluations: 74
# Optimization terminated successfully.
#          Current function value: -0.957079
#          Iterations: 62
#          Function evaluations: 1524
#          Gradient evaluations: 127
# Optimization terminated successfully.
#          Current function value: -0.957107
#          Iterations: 25
#          Function evaluations: 504
#          Gradient evaluations: 42
# Optimization terminated successfully.
#          Current function value: -0.957107
#          Iterations: 14
#          Function evaluations: 396
#          Gradient evaluations: 33
# Optimization terminated successfully.
#          Current function value: -0.957107
#          Iterations: 32
#          Function evaluations: 708
#          Gradient evaluations: 59
# Optimization terminated successfully.
#          Current function value: -0.957101
#          Iterations: 41
#          Function evaluations: 924
#          Gradient evaluations: 77
# Optimization terminated successfully.
#          Current function value: -0.749967
#          Iterations: 4
#          Function evaluations: 192
#          Gradient evaluations: 16
# Optimization terminated successfully.
#          Current function value: -0.957107
#          Iterations: 16
#          Function evaluations: 384
#          Gradient evaluations: 32
# Optimization terminated successfully.
#          Current function value: -0.957102
#          Iterations: 33
#          Function evaluations: 972
#          Gradient evaluations: 81
# Optimization terminated successfully.
#          Current function value: -0.749946
#          Iterations: 5
#          Function evaluations: 252
#          Gradient evaluations: 21
# Optimization terminated successfully.
#          Current function value: -0.957077
#          Iterations: 29
#          Function evaluations: 996
#          Gradient evaluations: 83
# Optimization terminated successfully.
#          Current function value: -0.957107
#          Iterations: 25
#          Function evaluations: 648
#          Gradient evaluations: 54
# Optimization terminated successfully.
#          Current function value: -0.957107
#          Iterations: 30
#          Function evaluations: 708
#          Gradient evaluations: 59
# Optimization terminated successfully.
#          Current function value: -0.249989
#          Iterations: 3
#          Function evaluations: 144
#          Gradient evaluations: 12
# Optimization terminated successfully.
#          Current function value: -0.957103
#          Iterations: 26
#          Function evaluations: 876
#          Gradient evaluations: 73
# Optimization terminated successfully.
#          Current function value: -0.957107
#          Iterations: 16
#          Function evaluations: 312
#          Gradient evaluations: 26
# Optimization terminated successfully.
#          Current function value: -0.957088
#          Iterations: 67
#          Function evaluations: 1512
#          Gradient evaluations: 126
# Optimization terminated successfully.
#          Current function value: -0.749945
#          Iterations: 4
#          Function evaluations: 228
#          Gradient evaluations: 19
# Optimization terminated successfully.
#          Current function value: -0.957107
#          Iterations: 22
#          Function evaluations: 576
#          Gradient evaluations: 48
# Optimization terminated successfully.
#          Current function value: -0.957057
#          Iterations: 22
#          Function evaluations: 708
#          Gradient evaluations: 59
# Optimization terminated successfully.
#          Current function value: -0.957099
#          Iterations: 79
#          Function evaluations: 1512
#          Gradient evaluations: 126
# Optimization terminated successfully.
#          Current function value: -0.957092
#          Iterations: 33
#          Function evaluations: 936
#          Gradient evaluations: 78
# Optimization terminated successfully.
#          Current function value: -0.957105
#          Iterations: 49
#          Function evaluations: 1176
#          Gradient evaluations: 98
# Optimization terminated successfully.
#          Current function value: -0.957066
#          Iterations: 24
#          Function evaluations: 768
#          Gradient evaluations: 64
# Optimization terminated successfully.
#          Current function value: -0.750000
#          Iterations: 2
#          Function evaluations: 96
#          Gradient evaluations: 8
# Optimization terminated successfully.
#          Current function value: -0.957107
#          Iterations: 17
#          Function evaluations: 492
#          Gradient evaluations: 41
# Optimization terminated successfully.
#          Current function value: -0.957107
#          Iterations: 14
#          Function evaluations: 372
#          Gradient evaluations: 31
# Optimization terminated successfully.
#          Current function value: -0.749933
#          Iterations: 6
#          Function evaluations: 288
#          Gradient evaluations: 24
# Optimization terminated successfully.
#          Current function value: -0.250012
#          Iterations: 1
#          Function evaluations: 60
#          Gradient evaluations: 5
# Optimization terminated successfully.
#          Current function value: -0.957104
#          Iterations: 36
#          Function evaluations: 1020
#          Gradient evaluations: 85
# Optimization terminated successfully.
#          Current function value: -0.957107
#          Iterations: 44
#          Function evaluations: 972
#          Gradient evaluations: 81
# Optimization terminated successfully.
#          Current function value: -0.957106
#          Iterations: 39
#          Function evaluations: 900
#          Gradient evaluations: 75
# Optimization terminated successfully.
#          Current function value: -0.957107
#          Iterations: 26
#          Function evaluations: 744
#          Gradient evaluations: 62
# Optimization terminated successfully.
#          Current function value: -0.957107
#          Iterations: 21
#          Function evaluations: 708
#          Gradient evaluations: 59
# Optimization terminated successfully.
#          Current function value: -0.749997
#          Iterations: 5
#          Function evaluations: 204
#          Gradient evaluations: 17
# Optimization terminated successfully.
#          Current function value: -0.957107
#          Iterations: 19
#          Function evaluations: 468
#          Gradient evaluations: 39
# Optimization terminated successfully.
#          Current function value: -0.957102
#          Iterations: 20
#          Function evaluations: 696
#          Gradient evaluations: 58
# Optimization terminated successfully.
#          Current function value: -0.957071
#          Iterations: 46
#          Function evaluations: 1080
#          Gradient evaluations: 90
# Optimization terminated successfully.
#          Current function value: -0.957105
#          Iterations: 42
#          Function evaluations: 1068
#          Gradient evaluations: 89
# Optimization terminated successfully.
#          Current function value: -0.957078
#          Iterations: 33
#          Function evaluations: 1080
#          Gradient evaluations: 90
# Optimization terminated successfully.
#          Current function value: -0.957102
#          Iterations: 21
#          Function evaluations: 660
#          Gradient evaluations: 55
# Optimization terminated successfully.
#          Current function value: -0.749975
#          Iterations: 2
#          Function evaluations: 72
#          Gradient evaluations: 6
# Optimization terminated successfully.
#          Current function value: -0.957107
#          Iterations: 14
#          Function evaluations: 276
#          Gradient evaluations: 23
# Optimization terminated successfully.
#          Current function value: -0.749934
#          Iterations: 6
#          Function evaluations: 276
#          Gradient evaluations: 23
# Optimization terminated successfully.
#          Current function value: -0.957107
#          Iterations: 18
#          Function evaluations: 360
#          Gradient evaluations: 30
# Optimization terminated successfully.
#          Current function value: -0.957092
#          Iterations: 60
#          Function evaluations: 1116
#          Gradient evaluations: 93
# Optimization terminated successfully.
#          Current function value: -0.957104
#          Iterations: 37
#          Function evaluations: 1236
#          Gradient evaluations: 103
# Optimization terminated successfully.
#          Current function value: -0.957083
#          Iterations: 40
#          Function evaluations: 1116
#          Gradient evaluations: 93
# Optimization terminated successfully.
#          Current function value: -0.749975
#          Iterations: 5
#          Function evaluations: 276
#          Gradient evaluations: 23
# Optimization terminated successfully.
#          Current function value: -0.957104
#          Iterations: 41
#          Function evaluations: 1164
#          Gradient evaluations: 97
# Optimization terminated successfully.
#          Current function value: -0.957104
#          Iterations: 64
#          Function evaluations: 1416
#          Gradient evaluations: 118
# Optimization terminated successfully.
#          Current function value: -0.749957
#          Iterations: 6
#          Function evaluations: 264
#          Gradient evaluations: 22
# Optimization terminated successfully.
#          Current function value: -0.957106
#          Iterations: 19
#          Function evaluations: 552
#          Gradient evaluations: 46
# Optimization terminated successfully.
#          Current function value: -0.957106
#          Iterations: 31
#          Function evaluations: 804
#          Gradient evaluations: 67
# Optimization terminated successfully.
#          Current function value: -0.957104
#          Iterations: 68
#          Function evaluations: 1464
#          Gradient evaluations: 122
# Optimization terminated successfully.
#          Current function value: -0.957083
#          Iterations: 80
#          Function evaluations: 1680
#          Gradient evaluations: 140
# Optimization terminated successfully.
#          Current function value: -0.957065
#          Iterations: 23
#          Function evaluations: 660
#          Gradient evaluations: 55
# Optimization terminated successfully.
#          Current function value: -0.957105
#          Iterations: 29
#          Function evaluations: 840
#          Gradient evaluations: 70
# Optimization terminated successfully.
#          Current function value: -0.957107
#          Iterations: 25
#          Function evaluations: 564
#          Gradient evaluations: 47
# Optimization terminated successfully.
#          Current function value: -0.957105
#          Iterations: 49
#          Function evaluations: 1272
#          Gradient evaluations: 106
# Optimization terminated successfully.
#          Current function value: -0.749990
#          Iterations: 3
#          Function evaluations: 132
#          Gradient evaluations: 11
# Optimization terminated successfully.
#          Current function value: -0.957107
#          Iterations: 25
#          Function evaluations: 696
#          Gradient evaluations: 58
# Optimization terminated successfully.
#          Current function value: -0.249991
#          Iterations: 5
#          Function evaluations: 264
#          Gradient evaluations: 22
# Optimization terminated successfully.
#          Current function value: -0.957107
#          Iterations: 22
#          Function evaluations: 600
#          Gradient evaluations: 50
# Optimization terminated successfully.
#          Current function value: -0.957099
#          Iterations: 20
#          Function evaluations: 732
#          Gradient evaluations: 61
# Optimization terminated successfully.
#          Current function value: -0.957064
#          Iterations: 25
#          Function evaluations: 768
#          Gradient evaluations: 64
# Optimization terminated successfully.
#          Current function value: -0.957107
#          Iterations: 24
#          Function evaluations: 600
#          Gradient evaluations: 50
# Optimization terminated successfully.
#          Current function value: -0.957106
#          Iterations: 17
#          Function evaluations: 612
#          Gradient evaluations: 51
# Optimization terminated successfully.
#          Current function value: -0.957107
#          Iterations: 13
#          Function evaluations: 252
#          Gradient evaluations: 21
# Optimization terminated successfully.
#          Current function value: -0.957044
#          Iterations: 22
#          Function evaluations: 804
#          Gradient evaluations: 67
# Optimization terminated successfully.
#          Current function value: -0.957105
#          Iterations: 31
#          Function evaluations: 852
#          Gradient evaluations: 71
# Optimization terminated successfully.
#          Current function value: -0.957107
#          Iterations: 19
#          Function evaluations: 528
#          Gradient evaluations: 44
# Optimization terminated successfully.
#          Current function value: -0.957104
#          Iterations: 77
#          Function evaluations: 1788
#          Gradient evaluations: 149
# Optimization terminated successfully.
#          Current function value: -0.957059
#          Iterations: 26
#          Function evaluations: 696
#          Gradient evaluations: 58
# Optimization terminated successfully.
#          Current function value: -0.749986
#          Iterations: 6
#          Function evaluations: 336
#          Gradient evaluations: 28
# Optimization terminated successfully.
#          Current function value: -0.957103
#          Iterations: 42
#          Function evaluations: 996
#          Gradient evaluations: 83
# Optimization terminated successfully.
#          Current function value: -0.957101
#          Iterations: 50
#          Function evaluations: 1404
#          Gradient evaluations: 117
# Optimization terminated successfully.
#          Current function value: -0.957063
#          Iterations: 25
#          Function evaluations: 924
#          Gradient evaluations: 77
# Optimization terminated successfully.
#          Current function value: -0.957098
#          Iterations: 34
#          Function evaluations: 1032
#          Gradient evaluations: 86
# Optimization terminated successfully.
#          Current function value: -0.957107
#          Iterations: 29
#          Function evaluations: 612
#          Gradient evaluations: 51
# Optimization terminated successfully.
#          Current function value: -0.749999
#          Iterations: 2
#          Function evaluations: 84
#          Gradient evaluations: 7
# Optimization terminated successfully.
#          Current function value: -0.957103
#          Iterations: 34
#          Function evaluations: 1296
#          Gradient evaluations: 108
# Optimization terminated successfully.
#          Current function value: -0.957107
#          Iterations: 27
#          Function evaluations: 696
#          Gradient evaluations: 58
# Optimization terminated successfully.
#          Current function value: -0.957106
#          Iterations: 30
#          Function evaluations: 756
#          Gradient evaluations: 63
# Optimization terminated successfully.
#          Current function value: -0.957103
#          Iterations: 35
#          Function evaluations: 972
#          Gradient evaluations: 81
# Optimization terminated successfully.
#          Current function value: -0.957107
#          Iterations: 28
#          Function evaluations: 600
#          Gradient evaluations: 50
# Optimization terminated successfully.
#          Current function value: -0.957079
#          Iterations: 27
#          Function evaluations: 612
#          Gradient evaluations: 51
# Optimization terminated successfully.
#          Current function value: -0.750001
#          Iterations: 5
#          Function evaluations: 216
#          Gradient evaluations: 18
# Optimization terminated successfully.
#          Current function value: -0.957089
#          Iterations: 29
#          Function evaluations: 756
#          Gradient evaluations: 63
# Optimization terminated successfully.
#          Current function value: -0.957096
#          Iterations: 24
#          Function evaluations: 732
#          Gradient evaluations: 61
# Optimization terminated successfully.
#          Current function value: -0.957093
#          Iterations: 40
#          Function evaluations: 1140
#          Gradient evaluations: 95
# Optimization terminated successfully.
#          Current function value: -0.957106
#          Iterations: 26
#          Function evaluations: 708
#          Gradient evaluations: 59
# Optimization terminated successfully.
#          Current function value: -0.249966
#          Iterations: 5
#          Function evaluations: 240
#          Gradient evaluations: 20
# Optimization terminated successfully.
#          Current function value: -0.957085
#          Iterations: 23
#          Function evaluations: 852
#          Gradient evaluations: 71
# Optimization terminated successfully.
#          Current function value: -0.749943
#          Iterations: 3
#          Function evaluations: 156
#          Gradient evaluations: 13
# Optimization terminated successfully.
#          Current function value: -0.957107
#          Iterations: 25
#          Function evaluations: 732
#          Gradient evaluations: 61
# Optimization terminated successfully.
#          Current function value: -0.749955
#          Iterations: 5
#          Function evaluations: 204
#          Gradient evaluations: 17
# Optimization terminated successfully.
#          Current function value: -0.957107
#          Iterations: 15
#          Function evaluations: 300
#          Gradient evaluations: 25
# Optimization terminated successfully.
#          Current function value: -0.957049
#          Iterations: 22
#          Function evaluations: 816
#          Gradient evaluations: 68
# Optimization terminated successfully.
#          Current function value: -0.957106
#          Iterations: 73
#          Function evaluations: 1548
#          Gradient evaluations: 129
# Optimization terminated successfully.
#          Current function value: -0.957107
#          Iterations: 15
#          Function evaluations: 480
#          Gradient evaluations: 40
# Optimization terminated successfully.
#          Current function value: -0.957103
#          Iterations: 33
#          Function evaluations: 948
#          Gradient evaluations: 79
# Optimization terminated successfully.
#          Current function value: -0.957105
#          Iterations: 62
#          Function evaluations: 1440
#          Gradient evaluations: 120
# Optimization terminated successfully.
#          Current function value: -0.957071
#          Iterations: 46
#          Function evaluations: 1008
#          Gradient evaluations: 84
# Optimization terminated successfully.
#          Current function value: -0.957107
#          Iterations: 18
#          Function evaluations: 396
#          Gradient evaluations: 33
# Optimization terminated successfully.
#          Current function value: -0.957100
#          Iterations: 38
#          Function evaluations: 1308
#          Gradient evaluations: 109
# Optimization terminated successfully.
#          Current function value: -0.957107
#          Iterations: 30
#          Function evaluations: 816
#          Gradient evaluations: 68
# Optimization terminated successfully.
#          Current function value: -0.250037
#          Iterations: 4
#          Function evaluations: 228
#          Gradient evaluations: 19
# Optimization terminated successfully.
#          Current function value: -0.957107
#          Iterations: 19
#          Function evaluations: 492
#          Gradient evaluations: 41
# Optimization terminated successfully.
#          Current function value: -0.749974
#          Iterations: 5
#          Function evaluations: 216
#          Gradient evaluations: 18
# Optimization terminated successfully.
#          Current function value: -0.749977
#          Iterations: 7
#          Function evaluations: 300
#          Gradient evaluations: 25
# Optimization terminated successfully.
#          Current function value: -0.750000
#          Iterations: 3
#          Function evaluations: 132
#          Gradient evaluations: 11
# Optimization terminated successfully.
#          Current function value: -0.957107
#          Iterations: 23
#          Function evaluations: 660
#          Gradient evaluations: 55
# Optimization terminated successfully.
#          Current function value: -0.957099
#          Iterations: 41
#          Function evaluations: 984
#          Gradient evaluations: 82
# Optimization terminated successfully.
#          Current function value: -0.957096
#          Iterations: 24
#          Function evaluations: 696
#          Gradient evaluations: 58
# Optimization terminated successfully.
#          Current function value: -0.957101
#          Iterations: 17
#          Function evaluations: 672
#          Gradient evaluations: 56
# Optimization terminated successfully.
#          Current function value: -0.749968
#          Iterations: 6
#          Function evaluations: 312
#          Gradient evaluations: 26
# Optimization terminated successfully.
#          Current function value: -0.957104
#          Iterations: 18
#          Function evaluations: 636
#          Gradient evaluations: 53
# Optimization terminated successfully.
#          Current function value: -0.957095
#          Iterations: 35
#          Function evaluations: 1044
#          Gradient evaluations: 87
# Optimization terminated successfully.
#          Current function value: -0.957100
#          Iterations: 48
#          Function evaluations: 1536
#          Gradient evaluations: 128
# Optimization terminated successfully.
#          Current function value: -0.750000
#          Iterations: 3
#          Function evaluations: 192
#          Gradient evaluations: 16
# Optimization terminated successfully.
#          Current function value: -0.957107
#          Iterations: 18
#          Function evaluations: 432
#          Gradient evaluations: 36
# Optimization terminated successfully.
#          Current function value: -0.957062
#          Iterations: 29
#          Function evaluations: 984
#          Gradient evaluations: 82
# Optimization terminated successfully.
#          Current function value: -0.750019
#          Iterations: 5
#          Function evaluations: 240
#          Gradient evaluations: 20
# Optimization terminated successfully.
#          Current function value: -0.957098
#          Iterations: 44
#          Function evaluations: 1044
#          Gradient evaluations: 87
# Optimization terminated successfully.
#          Current function value: -0.957078
#          Iterations: 48
#          Function evaluations: 1176
#          Gradient evaluations: 98
# Optimization terminated successfully.
#          Current function value: -0.957107
#          Iterations: 20
#          Function evaluations: 408
#          Gradient evaluations: 34
# Optimization terminated successfully.
#          Current function value: -0.957107
#          Iterations: 27
#          Function evaluations: 540
#          Gradient evaluations: 45
# Optimization terminated successfully.
#          Current function value: -0.957106
#          Iterations: 39
#          Function evaluations: 1140
#          Gradient evaluations: 95
# Optimization terminated successfully.
#          Current function value: -0.957092
#          Iterations: 36
#          Function evaluations: 960
#          Gradient evaluations: 80
# Optimization terminated successfully.
#          Current function value: -0.749963
#          Iterations: 4
#          Function evaluations: 144
#          Gradient evaluations: 12
# Optimization terminated successfully.
#          Current function value: -0.957078
#          Iterations: 32
#          Function evaluations: 1212
#          Gradient evaluations: 101
# Optimization terminated successfully.
#          Current function value: -0.957107
#          Iterations: 19
#          Function evaluations: 420
#          Gradient evaluations: 35
# Optimization terminated successfully.
#          Current function value: -0.957107
#          Iterations: 27
#          Function evaluations: 684
#          Gradient evaluations: 57
# Optimization terminated successfully.
#          Current function value: -0.957107
#          Iterations: 14
#          Function evaluations: 300
#          Gradient evaluations: 25
# Optimization terminated successfully.
#          Current function value: -0.957107
#          Iterations: 17
#          Function evaluations: 384
#          Gradient evaluations: 32
# Optimization terminated successfully.
#          Current function value: -0.957104
#          Iterations: 40
#          Function evaluations: 1428
#          Gradient evaluations: 119
# Optimization terminated successfully.
#          Current function value: -0.957102
#          Iterations: 53
#          Function evaluations: 1308
#          Gradient evaluations: 109
# Optimization terminated successfully.
#          Current function value: -0.957107
#          Iterations: 13
#          Function evaluations: 312
#          Gradient evaluations: 26
# Optimization terminated successfully.
#          Current function value: -0.749965
#          Iterations: 6
#          Function evaluations: 300
#          Gradient evaluations: 25
# Optimization terminated successfully.
#          Current function value: -0.749990
#          Iterations: 4
#          Function evaluations: 192
#          Gradient evaluations: 16
# Optimization terminated successfully.
#          Current function value: -0.749967
#          Iterations: 6
#          Function evaluations: 300
#          Gradient evaluations: 25
# Optimization terminated successfully.
#          Current function value: -0.957107
#          Iterations: 28
#          Function evaluations: 636
#          Gradient evaluations: 53
# Optimization terminated successfully.
#          Current function value: -0.749955
#          Iterations: 6
#          Function evaluations: 276
#          Gradient evaluations: 23
# Optimization terminated successfully.
#          Current function value: -0.749999
#          Iterations: 4
#          Function evaluations: 240
#          Gradient evaluations: 20
# Optimization terminated successfully.
#          Current function value: -0.957103
#          Iterations: 57
#          Function evaluations: 1476
#          Gradient evaluations: 123
# Optimization terminated successfully.
#          Current function value: -0.749975
#          Iterations: 4
#          Function evaluations: 180
#          Gradient evaluations: 15
# Optimization terminated successfully.
#          Current function value: -0.957061
#          Iterations: 24
#          Function evaluations: 984
#          Gradient evaluations: 82
# Optimization terminated successfully.
#          Current function value: -0.957106
#          Iterations: 33
#          Function evaluations: 1020
#          Gradient evaluations: 85
# Optimization terminated successfully.
#          Current function value: -0.749962
#          Iterations: 10
#          Function evaluations: 516
#          Gradient evaluations: 43
# Optimization terminated successfully.
#          Current function value: -0.749965
#          Iterations: 7
#          Function evaluations: 312
#          Gradient evaluations: 26
# Optimization terminated successfully.
#          Current function value: -0.749972
#          Iterations: 3
#          Function evaluations: 156
#          Gradient evaluations: 13
# Optimization terminated successfully.
#          Current function value: -0.957091
#          Iterations: 46
#          Function evaluations: 1368
#          Gradient evaluations: 114
# Optimization terminated successfully.
#          Current function value: -0.957106
#          Iterations: 47
#          Function evaluations: 1632
#          Gradient evaluations: 136
# Optimization terminated successfully.
#          Current function value: -0.749991
#          Iterations: 3
#          Function evaluations: 156
#          Gradient evaluations: 13
# Optimization terminated successfully.
#          Current function value: -0.957078
#          Iterations: 29
#          Function evaluations: 900
#          Gradient evaluations: 75
# Optimization terminated successfully.
#          Current function value: -0.957107
#          Iterations: 23
#          Function evaluations: 468
#          Gradient evaluations: 39
# Optimization terminated successfully.
#          Current function value: -0.957093
#          Iterations: 65
#          Function evaluations: 1488
#          Gradient evaluations: 124
# Optimization terminated successfully.
#          Current function value: -0.957104
#          Iterations: 21
#          Function evaluations: 504
#          Gradient evaluations: 42
# Optimization terminated successfully.
#          Current function value: -0.957106
#          Iterations: 37
#          Function evaluations: 864
#          Gradient evaluations: 72
# Optimization terminated successfully.
#          Current function value: -0.957107
#          Iterations: 31
#          Function evaluations: 816
#          Gradient evaluations: 68
# Optimization terminated successfully.
#          Current function value: -0.957106
#          Iterations: 31
#          Function evaluations: 756
#          Gradient evaluations: 63
# Optimization terminated successfully.
#          Current function value: -0.957057
#          Iterations: 24
#          Function evaluations: 828
#          Gradient evaluations: 69
# Optimization terminated successfully.
#          Current function value: -0.749974
#          Iterations: 5
#          Function evaluations: 252
#          Gradient evaluations: 21
# Optimization terminated successfully.
#          Current function value: -0.957107
#          Iterations: 25
#          Function evaluations: 636
#          Gradient evaluations: 53
# Optimization terminated successfully.
#          Current function value: -0.749957
#          Iterations: 3
#          Function evaluations: 156
#          Gradient evaluations: 13
# Optimization terminated successfully.
#          Current function value: -0.957091
#          Iterations: 27
#          Function evaluations: 828
#          Gradient evaluations: 69
# Optimization terminated successfully.
#          Current function value: -0.957075
#          Iterations: 75
#          Function evaluations: 1776
#          Gradient evaluations: 148
# Optimization terminated successfully.
#          Current function value: -0.957105
#          Iterations: 17
#          Function evaluations: 612
#          Gradient evaluations: 51
# Optimization terminated successfully.
#          Current function value: -0.957107
#          Iterations: 25
#          Function evaluations: 756
#          Gradient evaluations: 63
# Optimization terminated successfully.
#          Current function value: -0.957106
#          Iterations: 44
#          Function evaluations: 1068
#          Gradient evaluations: 89
# Optimization terminated successfully.
#          Current function value: -0.957054
#          Iterations: 31
#          Function evaluations: 768
#          Gradient evaluations: 64
# Optimization terminated successfully.
#          Current function value: -0.957097
#          Iterations: 29
#          Function evaluations: 708
#          Gradient evaluations: 59
# Optimization terminated successfully.
#          Current function value: -0.957107
#          Iterations: 25
#          Function evaluations: 660
#          Gradient evaluations: 55
# Optimization terminated successfully.
#          Current function value: -0.957107
#          Iterations: 45
#          Function evaluations: 1284
#          Gradient evaluations: 107
# Optimization terminated successfully.
#          Current function value: -0.957093
#          Iterations: 19
#          Function evaluations: 456
#          Gradient evaluations: 38
# Optimization terminated successfully.
#          Current function value: -0.957096
#          Iterations: 46
#          Function evaluations: 1272
#          Gradient evaluations: 106
# Optimization terminated successfully.
#          Current function value: -0.957078
#          Iterations: 55
#          Function evaluations: 1176
#          Gradient evaluations: 98
# Optimization terminated successfully.
#          Current function value: -0.957107
#          Iterations: 27
#          Function evaluations: 576
#          Gradient evaluations: 48
# Optimization terminated successfully.
#          Current function value: -0.957057
#          Iterations: 34
#          Function evaluations: 1032
#          Gradient evaluations: 86
# Optimization terminated successfully.
#          Current function value: -0.957089
#          Iterations: 82
#          Function evaluations: 1824
#          Gradient evaluations: 152
# Optimization terminated successfully.
#          Current function value: -0.957103
#          Iterations: 37
#          Function evaluations: 972
#          Gradient evaluations: 81
# Optimization terminated successfully.
#          Current function value: -0.749940
#          Iterations: 5
#          Function evaluations: 252
#          Gradient evaluations: 21
# Optimization terminated successfully.
#          Current function value: -0.749990
#          Iterations: 4
#          Function evaluations: 252
#          Gradient evaluations: 21
# Optimization terminated successfully.
#          Current function value: -0.957105
#          Iterations: 27
#          Function evaluations: 792
#          Gradient evaluations: 66
# Optimization terminated successfully.
#          Current function value: -0.957087
#          Iterations: 20
#          Function evaluations: 876
#          Gradient evaluations: 73
# Optimization terminated successfully.
#          Current function value: -0.749957
#          Iterations: 2
#          Function evaluations: 84
#          Gradient evaluations: 7
# Optimization terminated successfully.
#          Current function value: -0.957106
#          Iterations: 35
#          Function evaluations: 720
#          Gradient evaluations: 60
# Optimization terminated successfully.
#          Current function value: -0.750000
#          Iterations: 2
#          Function evaluations: 96
#          Gradient evaluations: 8
# Optimization terminated successfully.
#          Current function value: -0.957101
#          Iterations: 17
#          Function evaluations: 648
#          Gradient evaluations: 54
# Optimization terminated successfully.
#          Current function value: -0.957107
#          Iterations: 34
#          Function evaluations: 804
#          Gradient evaluations: 67
# Optimization terminated successfully.
#          Current function value: -0.749933
#          Iterations: 6
#          Function evaluations: 276
#          Gradient evaluations: 23
# Optimization terminated successfully.
#          Current function value: -0.957099
#          Iterations: 27
#          Function evaluations: 1116
#          Gradient evaluations: 93
# Optimization terminated successfully.
#          Current function value: -0.957104
#          Iterations: 60
#          Function evaluations: 1260
#          Gradient evaluations: 105
# Optimization terminated successfully.
#          Current function value: -0.957095
#          Iterations: 28
#          Function evaluations: 1056
#          Gradient evaluations: 88
# Optimization terminated successfully.
#          Current function value: -0.957107
#          Iterations: 28
#          Function evaluations: 684
#          Gradient evaluations: 57
# Optimization terminated successfully.
#          Current function value: -0.749938
#          Iterations: 8
#          Function evaluations: 312
#          Gradient evaluations: 26
# Optimization terminated successfully.
#          Current function value: -0.957093
#          Iterations: 64
#          Function evaluations: 1704
#          Gradient evaluations: 142
# Optimization terminated successfully.
#          Current function value: -0.957103
#          Iterations: 34
#          Function evaluations: 1092
#          Gradient evaluations: 91
# Optimization terminated successfully.
#          Current function value: -0.957097
#          Iterations: 31
#          Function evaluations: 876
#          Gradient evaluations: 73
# Optimization terminated successfully.
#          Current function value: -0.957107
#          Iterations: 12
#          Function evaluations: 240
#          Gradient evaluations: 20
# Optimization terminated successfully.
#          Current function value: -0.957107
#          Iterations: 17
#          Function evaluations: 348
#          Gradient evaluations: 29
# Optimization terminated successfully.
#          Current function value: -0.957068
#          Iterations: 37
#          Function evaluations: 1236
#          Gradient evaluations: 103
# Optimization terminated successfully.
#          Current function value: -0.957107
#          Iterations: 20
#          Function evaluations: 420
#          Gradient evaluations: 35
# Optimization terminated successfully.
#          Current function value: -0.957092
#          Iterations: 60
#          Function evaluations: 1260
#          Gradient evaluations: 105
# Optimization terminated successfully.
#          Current function value: -0.749999
#          Iterations: 5
#          Function evaluations: 240
#          Gradient evaluations: 20
# Optimization terminated successfully.
#          Current function value: -0.957107
#          Iterations: 19
#          Function evaluations: 492
#          Gradient evaluations: 41
# Optimization terminated successfully.
#          Current function value: -0.957092
#          Iterations: 39
#          Function evaluations: 1236
#          Gradient evaluations: 103
# Optimization terminated successfully.
#          Current function value: -0.957107
#          Iterations: 26
#          Function evaluations: 612
#          Gradient evaluations: 51
# Optimization terminated successfully.
#          Current function value: -0.957107
#          Iterations: 16
#          Function evaluations: 336
#          Gradient evaluations: 28
# Optimization terminated successfully.
#          Current function value: -0.749971
#          Iterations: 3
#          Function evaluations: 156
#          Gradient evaluations: 13
# Optimization terminated successfully.
#          Current function value: -0.957104
#          Iterations: 49
#          Function evaluations: 1248
#          Gradient evaluations: 104
# Optimization terminated successfully.
#          Current function value: -0.957103
#          Iterations: 27
#          Function evaluations: 852
#          Gradient evaluations: 71
# Optimization terminated successfully.
#          Current function value: -0.749971
#          Iterations: 12
#          Function evaluations: 588
#          Gradient evaluations: 49
# Optimization terminated successfully.
#          Current function value: -0.957106
#          Iterations: 23
#          Function evaluations: 588
#          Gradient evaluations: 49
# Optimization terminated successfully.
#          Current function value: -0.957107
#          Iterations: 16
#          Function evaluations: 768
#          Gradient evaluations: 64
# Optimization terminated successfully.
#          Current function value: -0.749994
#          Iterations: 3
#          Function evaluations: 120
#          Gradient evaluations: 10
# Optimization terminated successfully.
#          Current function value: -0.957096
#          Iterations: 41
#          Function evaluations: 1188
#          Gradient evaluations: 99
# Optimization terminated successfully.
#          Current function value: -0.957103
#          Iterations: 26
#          Function evaluations: 792
#          Gradient evaluations: 66
# Optimization terminated successfully.
#          Current function value: -0.957107
#          Iterations: 18
#          Function evaluations: 372
#          Gradient evaluations: 31
# Optimization terminated successfully.
#          Current function value: -0.957106
#          Iterations: 30
#          Function evaluations: 756
#          Gradient evaluations: 63
# Optimization terminated successfully.
#          Current function value: -0.957082
#          Iterations: 26
#          Function evaluations: 540
#          Gradient evaluations: 45
# Optimization terminated successfully.
#          Current function value: -0.957107
#          Iterations: 23
#          Function evaluations: 624
#          Gradient evaluations: 52
# Optimization terminated successfully.
#          Current function value: -0.957085
#          Iterations: 39
#          Function evaluations: 1248
#          Gradient evaluations: 104
# Optimization terminated successfully.
#          Current function value: -0.957107
#          Iterations: 11
#          Function evaluations: 216
#          Gradient evaluations: 18
# Optimization terminated successfully.
#          Current function value: -0.957101
#          Iterations: 61
#          Function evaluations: 1500
#          Gradient evaluations: 125
# Optimization terminated successfully.
#          Current function value: -0.249969
#          Iterations: 3
#          Function evaluations: 180
#          Gradient evaluations: 15
# Optimization terminated successfully.
#          Current function value: -0.957106
#          Iterations: 24
#          Function evaluations: 636
#          Gradient evaluations: 53
# Optimization terminated successfully.
#          Current function value: -0.957060
#          Iterations: 35
#          Function evaluations: 816
#          Gradient evaluations: 68
# Optimization terminated successfully.
#          Current function value: -0.749960
#          Iterations: 8
#          Function evaluations: 312
#          Gradient evaluations: 26
# Optimization terminated successfully.
#          Current function value: -0.957106
#          Iterations: 42
#          Function evaluations: 960
#          Gradient evaluations: 80
# Optimization terminated successfully.
#          Current function value: -0.749975
#          Iterations: 4
#          Function evaluations: 204
#          Gradient evaluations: 17
# Optimization terminated successfully.
#          Current function value: -0.957107
#          Iterations: 19
#          Function evaluations: 468
#          Gradient evaluations: 39
# Optimization terminated successfully.
#          Current function value: -0.957106
#          Iterations: 38
#          Function evaluations: 1092
#          Gradient evaluations: 91
# Optimization terminated successfully.
#          Current function value: -0.957062
#          Iterations: 33
#          Function evaluations: 1176
#          Gradient evaluations: 98
# Optimization terminated successfully.
#          Current function value: -0.749919
#          Iterations: 7
#          Function evaluations: 312
#          Gradient evaluations: 26
# Optimization terminated successfully.
#          Current function value: -0.957106
#          Iterations: 36
#          Function evaluations: 1140
#          Gradient evaluations: 95
# Optimization terminated successfully.
#          Current function value: -0.957107
#          Iterations: 21
#          Function evaluations: 456
#          Gradient evaluations: 38
# Optimization terminated successfully.
#          Current function value: -0.957093
#          Iterations: 41
#          Function evaluations: 1068
#          Gradient evaluations: 89
# Optimization terminated successfully.
#          Current function value: -0.957106
#          Iterations: 25
#          Function evaluations: 588
#          Gradient evaluations: 49
# Optimization terminated successfully.
#          Current function value: -0.957101
#          Iterations: 33
#          Function evaluations: 996
#          Gradient evaluations: 83
# Optimization terminated successfully.
#          Current function value: -0.957094
#          Iterations: 28
#          Function evaluations: 852
#          Gradient evaluations: 71
# Optimization terminated successfully.
#          Current function value: -0.957106
#          Iterations: 38
#          Function evaluations: 1080
#          Gradient evaluations: 90
# Optimization terminated successfully.
#          Current function value: -0.749954
#          Iterations: 4
#          Function evaluations: 180
#          Gradient evaluations: 15
# Optimization terminated successfully.
#          Current function value: -0.957086
#          Iterations: 45
#          Function evaluations: 1416
#          Gradient evaluations: 118
# Optimization terminated successfully.
#          Current function value: -0.957106
#          Iterations: 28
#          Function evaluations: 1092
#          Gradient evaluations: 91
# Optimization terminated successfully.
#          Current function value: -0.957107
#          Iterations: 15
#          Function evaluations: 348
#          Gradient evaluations: 29
# Optimization terminated successfully.
#          Current function value: -0.750000
#          Iterations: 4
#          Function evaluations: 216
#          Gradient evaluations: 18
# Optimization terminated successfully.
#          Current function value: -0.957104
#          Iterations: 52
#          Function evaluations: 1284
#          Gradient evaluations: 107
# Optimization terminated successfully.
#          Current function value: -0.957101
#          Iterations: 28
#          Function evaluations: 828
#          Gradient evaluations: 69
# Optimization terminated successfully.
#          Current function value: -0.957106
#          Iterations: 27
#          Function evaluations: 612
#          Gradient evaluations: 51
# Optimization terminated successfully.
#          Current function value: -0.957088
#          Iterations: 51
#          Function evaluations: 1452
#          Gradient evaluations: 121
# Optimization terminated successfully.
#          Current function value: -0.957051
#          Iterations: 20
#          Function evaluations: 684
#          Gradient evaluations: 57
# Optimization terminated successfully.
#          Current function value: -0.957085
#          Iterations: 22
#          Function evaluations: 768
#          Gradient evaluations: 64
# Optimization terminated successfully.
#          Current function value: -0.957082
#          Iterations: 49
#          Function evaluations: 1308
#          Gradient evaluations: 109
# Optimization terminated successfully.
#          Current function value: -0.957076
#          Iterations: 31
#          Function evaluations: 1104
#          Gradient evaluations: 92
# Optimization terminated successfully.
#          Current function value: -0.957103
#          Iterations: 66
#          Function evaluations: 1632
#          Gradient evaluations: 136
# Optimization terminated successfully.
#          Current function value: -0.957107
#          Iterations: 20
#          Function evaluations: 564
#          Gradient evaluations: 47
# Optimization terminated successfully.
#          Current function value: -0.957106
#          Iterations: 32
#          Function evaluations: 1164
#          Gradient evaluations: 97
# Optimization terminated successfully.
#          Current function value: -0.749972
#          Iterations: 3
#          Function evaluations: 180
#          Gradient evaluations: 15
# Optimization terminated successfully.
#          Current function value: -0.957105
#          Iterations: 29
#          Function evaluations: 672
#          Gradient evaluations: 56
# Optimization terminated successfully.
#          Current function value: -0.957096
#          Iterations: 27
#          Function evaluations: 1008
#          Gradient evaluations: 84
# Optimization terminated successfully.
#          Current function value: -0.957107
#          Iterations: 18
#          Function evaluations: 384
#          Gradient evaluations: 32
# Optimization terminated successfully.
#          Current function value: -0.957107
#          Iterations: 30
#          Function evaluations: 684
#          Gradient evaluations: 57
# Optimization terminated successfully.
#          Current function value: -0.957104
#          Iterations: 54
#          Function evaluations: 1284
#          Gradient evaluations: 107
# Optimization terminated successfully.
#          Current function value: -0.957089
#          Iterations: 48
#          Function evaluations: 1140
#          Gradient evaluations: 95
# Optimization terminated successfully.
#          Current function value: -0.957107
#          Iterations: 19
#          Function evaluations: 468
#          Gradient evaluations: 39
# Optimization terminated successfully.
#          Current function value: -0.957107
#          Iterations: 17
#          Function evaluations: 312
#          Gradient evaluations: 26
# Optimization terminated successfully.
#          Current function value: -0.957107
#          Iterations: 27
#          Function evaluations: 684
#          Gradient evaluations: 57
# Optimization terminated successfully.
#          Current function value: -0.749997
#          Iterations: 4
#          Function evaluations: 216
#          Gradient evaluations: 18
# Optimization terminated successfully.
#          Current function value: -0.957106
#          Iterations: 25
#          Function evaluations: 684
#          Gradient evaluations: 57
# Optimization terminated successfully.
#          Current function value: -0.957106
#          Iterations: 35
#          Function evaluations: 1212
#          Gradient evaluations: 101
# Optimization terminated successfully.
#          Current function value: -0.957107
#          Iterations: 14
#          Function evaluations: 312
#          Gradient evaluations: 26
# Optimization terminated successfully.
#          Current function value: -0.957107
# ...
#          Iterations: 30
#          Function evaluations: 828
#          Gradient evaluations: 69
# Optimization terminated successfully.
#          Current function value: -0.957103
#          Iterations: 24
#          Function evaluations: 780
#          Gradient evaluations: 65
# Optimization terminated successfully.
#          Current function value: -0.957107
#          Iterations: 26
#          Function evaluations: 696
#          Gradient evaluations: 58
# Optimization terminated successfully.
#          Current function value: -0.957096
#          Iterations: 47
#          Function evaluations: 1308
#          Gradient evaluations: 109
# Optimization terminated successfully.
#          Current function value: -0.957106
#          Iterations: 30
#          Function evaluations: 984
#          Gradient evaluations: 82
# Optimization terminated successfully.
#          Current function value: -0.957107
#          Iterations: 27
#          Function evaluations: 636
#          Gradient evaluations: 53
# Optimization terminated successfully.
#          Current function value: -0.957107
#          Iterations: 15
#          Function evaluations: 336
#          Gradient evaluations: 28
# Optimization terminated successfully.
#          Current function value: -0.750015
#          Iterations: 3
#          Function evaluations: 144
#          Gradient evaluations: 12
# Optimization terminated successfully.
#          Current function value: -0.957074
#          Iterations: 51
#          Function evaluations: 1164
#          Gradient evaluations: 97
# Optimization terminated successfully.
#          Current function value: -0.957101
#          Iterations: 60
#          Function evaluations: 1428
#          Gradient evaluations: 119
# Optimization terminated successfully.
#          Current function value: -0.957106
#          Iterations: 60
#          Function evaluations: 1452
#          Gradient evaluations: 121
# Optimization terminated successfully.
#          Current function value: -0.957103
#          Iterations: 23
#          Function evaluations: 948
#          Gradient evaluations: 79
# Optimization terminated successfully.
#          Current function value: -0.750000
#          Iterations: 5
#          Function evaluations: 252
#          Gradient evaluations: 21
# Optimization terminated successfully.
#          Current function value: -0.749968
#          Iterations: 7
#          Function evaluations: 288
#          Gradient evaluations: 24
# Optimization terminated successfully.
#          Current function value: -0.957106
#          Iterations: 29
#          Function evaluations: 912
#          Gradient evaluations: 76
# Optimization terminated successfully.
#          Current function value: -0.957107
#          Iterations: 16
#          Function evaluations: 420
#          Gradient evaluations: 35
# Optimization terminated successfully.
#          Current function value: -0.957107
#          Iterations: 13
#          Function evaluations: 456
#          Gradient evaluations: 38
# Optimization terminated successfully.
#          Current function value: -0.957100
#          Iterations: 61
#          Function evaluations: 1260
#          Gradient evaluations: 105
# Optimization terminated successfully.
#          Current function value: -0.957049
#          Iterations: 25
#          Function evaluations: 972
#          Gradient evaluations: 81
# Optimization terminated successfully.
#          Current function value: -0.749970
#          Iterations: 6
#          Function evaluations: 288
#          Gradient evaluations: 24
# Optimization terminated successfully.
#          Current function value: -0.957107
#          Iterations: 24
#          Function evaluations: 756
#          Gradient evaluations: 63
# Optimization terminated successfully.
#          Current function value: -0.249959
#          Iterations: 6
#          Function evaluations: 288
#          Gradient evaluations: 24
# Optimization terminated successfully.
#          Current function value: -0.957104
#          Iterations: 36
#          Function evaluations: 900
#          Gradient evaluations: 75
# Optimization terminated successfully.
#          Current function value: -0.957096
#          Iterations: 29
#          Function evaluations: 960
#          Gradient evaluations: 80
# Optimization terminated successfully.
#          Current function value: -0.957107
#          Iterations: 23
#          Function evaluations: 444
#          Gradient evaluations: 37
# Optimization terminated successfully.
#          Current function value: -0.957106
#          Iterations: 30
#          Function evaluations: 1296
#          Gradient evaluations: 108
# Optimization terminated successfully.
#          Current function value: -0.957080
#          Iterations: 27
#          Function evaluations: 996
#          Gradient evaluations: 83
# Optimization terminated successfully.
#          Current function value: -0.957094
#          Iterations: 32
#          Function evaluations: 1008
#          Gradient evaluations: 84
# Optimization terminated successfully.
#          Current function value: -0.957107
#          Iterations: 18
#          Function evaluations: 444
#          Gradient evaluations: 37
# Optimization terminated successfully.
#          Current function value: -0.957092
#          Iterations: 49
#          Function evaluations: 1248
#          Gradient evaluations: 104
# Optimization terminated successfully.
#          Current function value: -0.957107
#          Iterations: 26
#          Function evaluations: 624
#          Gradient evaluations: 52
# Optimization terminated successfully.
#          Current function value: -0.957101
#          Iterations: 32
#          Function evaluations: 840
#          Gradient evaluations: 70
# Optimization terminated successfully.
#          Current function value: -0.957105
#          Iterations: 50
#          Function evaluations: 1164
#          Gradient evaluations: 97
# Optimization terminated successfully.
#          Current function value: -0.957107
#          Iterations: 25
#          Function evaluations: 588
#          Gradient evaluations: 49
# Optimization terminated successfully.
#          Current function value: -0.957106
#          Iterations: 27
#          Function evaluations: 648
#          Gradient evaluations: 54
# Optimization terminated successfully.
#          Current function value: -0.957107
#          Iterations: 16
#          Function evaluations: 384
#          Gradient evaluations: 32
# Optimization terminated successfully.
#          Current function value: -0.957085
#          Iterations: 33
#          Function evaluations: 1128
#          Gradient evaluations: 94
# Optimization terminated successfully.
#          Current function value: -0.957107
#          Iterations: 17
#          Function evaluations: 336
#          Gradient evaluations: 28
# Optimization terminated successfully.
#          Current function value: -0.957107
#          Iterations: 29
#          Function evaluations: 672
#          Gradient evaluations: 56
# Optimization terminated successfully.
#          Current function value: -0.957054
#          Iterations: 100
#          Function evaluations: 3588
#          Gradient evaluations: 299
# Optimization terminated successfully.
#          Current function value: -0.957107
#          Iterations: 19
#          Function evaluations: 432
#          Gradient evaluations: 36
# Optimization terminated successfully.
#          Current function value: -0.957085
#          Iterations: 35
#          Function evaluations: 924
#          Gradient evaluations: 77
# Optimization terminated successfully.
#          Current function value: -0.750000
#          Iterations: 4
#          Function evaluations: 168
#          Gradient evaluations: 14
# Optimization terminated successfully.
#          Current function value: -0.957084
#          Iterations: 44
#          Function evaluations: 1212
#          Gradient evaluations: 101
# Optimization terminated successfully.
#          Current function value: -0.749927
#          Iterations: 7
#          Function evaluations: 324
#          Gradient evaluations: 27
# Optimization terminated successfully.
#          Current function value: -0.957086
#          Iterations: 47
#          Function evaluations: 1296
#          Gradient evaluations: 108
# Optimization terminated successfully.
#          Current function value: -0.957107
#          Iterations: 30
#          Function evaluations: 636
#          Gradient evaluations: 53
# Optimization terminated successfully.
#          Current function value: -0.957065
#          Iterations: 35
#          Function evaluations: 936
#          Gradient evaluations: 78
# Optimization terminated successfully.
#          Current function value: -0.749955
#          Iterations: 6
#          Function evaluations: 276
#          Gradient evaluations: 23
# Optimization terminated successfully.
#          Current function value: -0.957107
#          Iterations: 18
#          Function evaluations: 348
#          Gradient evaluations: 29
# Optimization terminated successfully.
#          Current function value: -0.749979
#          Iterations: 2
#          Function evaluations: 108
#          Gradient evaluations: 9
# Optimization terminated successfully.
#          Current function value: -0.957097
#          Iterations: 24
#          Function evaluations: 900
#          Gradient evaluations: 75
# Optimization terminated successfully.
#          Current function value: -0.957101
#          Iterations: 47
#          Function evaluations: 1236
#          Gradient evaluations: 103
# Optimization terminated successfully.
#          Current function value: -0.750000
#          Iterations: 2
#          Function evaluations: 120
#          Gradient evaluations: 10
# Optimization terminated successfully.
#          Current function value: -0.957106
#          Iterations: 52
#          Function evaluations: 1236
#          Gradient evaluations: 103
# Optimization terminated successfully.
#          Current function value: -0.957107
#          Iterations: 15
#          Function evaluations: 336
#          Gradient evaluations: 28
# Optimization terminated successfully.
#          Current function value: -0.249993
#          Iterations: 2
#          Function evaluations: 72
#          Gradient evaluations: 6
# Optimization terminated successfully.
#          Current function value: -0.749954
#          Iterations: 4
#          Function evaluations: 204
#          Gradient evaluations: 17
# Optimization terminated successfully.
#          Current function value: -0.957086
#          Iterations: 39
#          Function evaluations: 1224
#          Gradient evaluations: 102
# Optimization terminated successfully.
#          Current function value: -0.957081
#          Iterations: 62
#          Function evaluations: 1584
#          Gradient evaluations: 132
# Optimization terminated successfully.
#          Current function value: -0.957106
#          Iterations: 27
#          Function evaluations: 768
#          Gradient evaluations: 64
# Optimization terminated successfully.
#          Current function value: -0.957101
#          Iterations: 68
#          Function evaluations: 1572
#          Gradient evaluations: 131
# Optimization terminated successfully.
#          Current function value: -0.957104
#          Iterations: 40
#          Function evaluations: 1236
#          Gradient evaluations: 103
# Optimization terminated successfully.
#          Current function value: -0.957107
#          Iterations: 22
#          Function evaluations: 492
#          Gradient evaluations: 41
# Optimization terminated successfully.
#          Current function value: -0.957107
#          Iterations: 18
#          Function evaluations: 456
#          Gradient evaluations: 38
# Optimization terminated successfully.
#          Current function value: -0.957107
#          Iterations: 16
#          Function evaluations: 312
#          Gradient evaluations: 26
# Optimization terminated successfully.
#          Current function value: -0.957084
#          Iterations: 63
#          Function evaluations: 1752
#          Gradient evaluations: 146
# Optimization terminated successfully.
#          Current function value: -0.957106
#          Iterations: 17
#          Function evaluations: 408
#          Gradient evaluations: 34
# Optimization terminated successfully.
#          Current function value: -0.957106
#          Iterations: 25
#          Function evaluations: 480
#          Gradient evaluations: 40
# Optimization terminated successfully.
#          Current function value: -0.957107
#          Iterations: 33
#          Function evaluations: 600
#          Gradient evaluations: 50
# Optimization terminated successfully.
#          Current function value: -0.957094
#          Iterations: 46
#          Function evaluations: 1248
#          Gradient evaluations: 104
# Optimization terminated successfully.
#          Current function value: -0.749960
#          Iterations: 3
#          Function evaluations: 156
#          Gradient evaluations: 13
# Optimization terminated successfully.
#          Current function value: -0.957104
#          Iterations: 27
#          Function evaluations: 816
#          Gradient evaluations: 68
# Optimization terminated successfully.
#          Current function value: -0.957107
#          Iterations: 12
#          Function evaluations: 252
#          Gradient evaluations: 21
# Optimization terminated successfully.
#          Current function value: -0.957104
#          Iterations: 35
#          Function evaluations: 1116
#          Gradient evaluations: 93
# Optimization terminated successfully.
#          Current function value: -0.957106
#          Iterations: 35
#          Function evaluations: 960
#          Gradient evaluations: 80
# Optimization terminated successfully.
#          Current function value: -0.957080
#          Iterations: 26
#          Function evaluations: 1032
#          Gradient evaluations: 86
# Optimization terminated successfully.
#          Current function value: -0.957100
#          Iterations: 20
#          Function evaluations: 636
#          Gradient evaluations: 53
# Optimization terminated successfully.
#          Current function value: -0.749987
#          Iterations: 8
#          Function evaluations: 384
#          Gradient evaluations: 32
# Optimization terminated successfully.
#          Current function value: -0.957107
#          Iterations: 36
#          Function evaluations: 840
#          Gradient evaluations: 70
# Optimization terminated successfully.
#          Current function value: -0.957104
#          Iterations: 34
#          Function evaluations: 1224
#          Gradient evaluations: 102
# Optimization terminated successfully.
#          Current function value: -0.957095
#          Iterations: 54
#          Function evaluations: 1524
#          Gradient evaluations: 127
# Optimization terminated successfully.
#          Current function value: -0.957101
#          Iterations: 37
#          Function evaluations: 852
#          Gradient evaluations: 71
# Optimization terminated successfully.
#          Current function value: -0.957105
#          Iterations: 43
#          Function evaluations: 1320
#          Gradient evaluations: 110
# Optimization terminated successfully.
#          Current function value: -0.957098
#          Iterations: 38
#          Function evaluations: 1152
#          Gradient evaluations: 96
# Optimization terminated successfully.
#          Current function value: -0.957106
#          Iterations: 44
#          Function evaluations: 1284
#          Gradient evaluations: 107
# Optimization terminated successfully.
#          Current function value: -0.957106
#          Iterations: 20
#          Function evaluations: 516
#          Gradient evaluations: 43
# Optimization terminated successfully.
#          Current function value: -0.957074
#          Iterations: 28
#          Function evaluations: 852
#          Gradient evaluations: 71
# Optimization terminated successfully.
#          Current function value: -0.957106
#          Iterations: 37
#          Function evaluations: 768
#          Gradient evaluations: 64
# Optimization terminated successfully.
#          Current function value: -0.957095
#          Iterations: 46
#          Function evaluations: 1344
#          Gradient evaluations: 112
# Optimization terminated successfully.
#          Current function value: -0.749945
#          Iterations: 7
#          Function evaluations: 288
#          Gradient evaluations: 24
# Optimization terminated successfully.
#          Current function value: -0.957091
#          Iterations: 18
#          Function evaluations: 768
#          Gradient evaluations: 64

# %%
plt.figure(constrained_layout=True)
plt.figure(figsize=(10,10))
ttl = plt.suptitle("N = 2, M = 1, B = 1",size =20)
gs = gridspec.GridSpec(ncols=3, nrows=3, hspace = 0.4)
ttl.set_position([.5, 0.92])



ax1 = plt.subplot(gs[0, 0])
ax1 .hist(cgdStateErr, bins=10) 
ax1 .set_xlabel("$1-|<\Psi_{RBM}|\Psi_{ED}>|^2$",size = 15)
ax1.set_ylabel("Frequency",size = 15)



ax2 = plt.subplot(gs[0, 1])
ax2.hist(cgdEngErr, bins=10) 
ax2.set_xlabel("$\Delta E = |E_{RBM}-E_{ED}|$",size = 15)



ax3 = plt.subplot(gs[0, 2])
ax3.hist(cgdTime, bins=10) 
ax3.set_xlabel("Runtime",size = 15)


ax4 = plt.subplot(gs[1, :])
ax4.scatter(hisIt,cgdEngErr) 
ax4 .set_ylabel("$\Delta E = |E_{RBM}-E_{ED}|$", size = 15)


ax5 = plt.subplot(gs[2, :])
ax5.scatter(hisIt,cgdTime)  
ax5.set_xlabel("Run Number",size = 15)
ax5 .set_ylabel("Runtime", size = 15)
# Out:
# Text(0, 0.5, 'Runtime')

# %%
avEngErr = np.sum(cgdEngErr)/(len(hisIt))
avStateErr = np.sum(cgdStateErr)/(len(hisIt))
avRunTime = np.sum(cgdTime)/(len(hisIt))
relativeErr = np.abs(cgdEngErr/ActualEng[0])
avRelativeErr = np.sum(relativeErr)/(len(hisIt))
print('Average Energy Error: ', avEngErr )
print('Average Ground State Error: ', avStateErr )
print('Average Run Time: ', avRunTime )
print('Average Relative Energy Error: ', avRelativeErr)

cutOff = 0.01
runsCutOff = sum(i>cutOff for i in relativeErr)
prob = (runsCutOff/500)
print("Number of runs below 0.01 relative error:", runsCutOff )
print("Prob of issue:",  f"{prob:.4f}" )
print("Prob of issue two runs:", f"{prob**2:.4f}" )
print("Prob of issue three runs:", f"{prob**3:.5f}" )
# Out:
# Average Energy Error:  0.05426149330244973
# Average Ground State Error:  0.037587032522622695
# Average Run Time:  3.56232008600235
# Average Relative Energy Error:  0.056693249247675895
# Number of runs below 0.01 relative error: 102
# Prob of issue: 0.2040
# Prob of issue two runs: 0.0416
# Prob of issue three runs: 0.00849

# %%
#Parameter definition 
N= 2
M=1
B = 1
A0 = 1

cgdConResults = [] #gives ground state estimation at each iteration of gd
cgdConState = []
cgdConTime = []
cgdConEngErr = []
cgdConStateErr = []
cgdConRuns = []

edState = []
edTime = []
ActualEng = []

hisIt = np.arange(20)

# %%
for i in range(len(hisIt)):
    
    
    #gradient descent
    cgdCon,cgdConErrTemp,runs = CgdConvergance(N, M, B, A0)

    cgdConResults.append(cgdCon)
    cgdConState.append(cgdCon[0])
    cgdConTime.append(cgdCon[1])
    cgdConRuns.append(runs)
    
    
    #exact diagonalization 
    groundState = GroundState(N,B,A0)
    ed = groundState()
    edState.append(ed[0])
    edTime.append(ed[1])
    
    
    #Error
    cgdConEngTemp = cgdCon[0][2]
    edEngTemp = ed[0][0]
    
    ActualEng.append(edEngTemp)
    cgdConStateTemp = cgdCon[0][1]
    edStateTemp = ed[0][1]

    cgdConEngErr.append(cgdConErrTemp[0])
    cgdConStateErr.append(cgdConErrTemp[1])
# Out:
# Optimization terminated successfully.
#          Current function value: -0.957107
#          Iterations: 23
#          Function evaluations: 540
#          Gradient evaluations: 45
# relativeErr 6.1576698177561675e-09
# Optimization terminated successfully.
#          Current function value: -0.957107
#          Iterations: 19
#          Function evaluations: 516
#          Gradient evaluations: 43
# relativeErr 6.45096021999128e-10
# Optimization terminated successfully.
#          Current function value: -0.957103
#          Iterations: 32
#          Function evaluations: 792
#          Gradient evaluations: 66
# relativeErr 3.8127532575609237e-06
# Optimization terminated successfully.
#          Current function value: -0.957106
#          Iterations: 34
#          Function evaluations: 840
#          Gradient evaluations: 70
# relativeErr 9.423716725655631e-07
# Optimization terminated successfully.
#          Current function value: -0.957096
#          Iterations: 35
#          Function evaluations: 936
#          Gradient evaluations: 78
# relativeErr 1.1018825199800548e-05
# Optimization terminated successfully.
#          Current function value: -0.750000
#          Iterations: 5
#          Function evaluations: 204
#          Gradient evaluations: 17
# relativeErr 0.21638841034044562
# Optimization terminated successfully.
#          Current function value: -0.957107
#          Iterations: 22
#          Function evaluations: 492
#          Gradient evaluations: 41
# relativeErr in Loop 7.892071799267579e-08
# Optimization terminated successfully.
#          Current function value: -0.957099
#          Iterations: 35
#          Function evaluations: 1308
#          Gradient evaluations: 109
# relativeErr 7.753326182907854e-06
# Optimization terminated successfully.
#          Current function value: -0.957095
#          Iterations: 34
#          Function evaluations: 1044
#          Gradient evaluations: 87
# relativeErr 1.1846172735529271e-05
# Optimization terminated successfully.
#          Current function value: -0.957107
#          Iterations: 15
#          Function evaluations: 300
#          Gradient evaluations: 25
# relativeErr 2.1837721053554846e-09
# Optimization terminated successfully.
#          Current function value: -0.957107
#          Iterations: 19
#          Function evaluations: 396
#          Gradient evaluations: 33
# relativeErr 3.3922391595279787e-10
# Optimization terminated successfully.
#          Current function value: -0.957106
#          Iterations: 36
#          Function evaluations: 996
#          Gradient evaluations: 83
# relativeErr 5.683627806182652e-07
# Optimization terminated successfully.
#          Current function value: -0.957107
#          Iterations: 33
#          Function evaluations: 888
#          Gradient evaluations: 74
# relativeErr 8.02874740513837e-09
# Optimization terminated successfully.
#          Current function value: -0.749942
#          Iterations: 6
#          Function evaluations: 276
#          Gradient evaluations: 23
# relativeErr 0.21644866065320253
# Optimization terminated successfully.
#          Current function value: -0.750006
#          Iterations: 5
#          Function evaluations: 240
#          Gradient evaluations: 20
# relativeErr in Loop 0.2163818923002813
# Optimization terminated successfully.
#          Current function value: -0.957101
#          Iterations: 37
#          Function evaluations: 732
#          Gradient evaluations: 61
# relativeErr in Loop 5.642533935285253e-06
# Optimization terminated successfully.
#          Current function value: -0.957082
#          Iterations: 34
#          Function evaluations: 948
#          Gradient evaluations: 79
# relativeErr 2.6341987093876876e-05
# Optimization terminated successfully.
#          Current function value: -0.957107
#          Iterations: 28
#          Function evaluations: 720
#          Gradient evaluations: 60
# relativeErr 3.102596076823923e-10
# Optimization terminated successfully.
#          Current function value: -0.957098
#          Iterations: 82
#          Function evaluations: 1812
#          Gradient evaluations: 151
# relativeErr 9.028044907801453e-06
# Optimization terminated successfully.
#          Current function value: -0.957107
#          Iterations: 15
#          Function evaluations: 360
#          Gradient evaluations: 30
# relativeErr 9.116415834991018e-09
# Optimization terminated successfully.
#          Current function value: -0.957106
#          Iterations: 29
#          Function evaluations: 1032
#          Gradient evaluations: 86
# relativeErr 4.057382487791045e-07
# Optimization terminated successfully.
#          Current function value: -0.957107
#          Iterations: 38
#          Function evaluations: 864
#          Gradient evaluations: 72
# relativeErr 8.827437686604549e-08
# Optimization terminated successfully.
#          Current function value: -0.957067
#          Iterations: 32
#          Function evaluations: 1308
#          Gradient evaluations: 109
# relativeErr 4.1734838576732336e-05

# %%
plt.figure(constrained_layout=True)
plt.figure(figsize=(10,10))
ttl = plt.suptitle("N = 2, M = 1, B = 1 With Multiple Attempts",size =20)
gs = gridspec.GridSpec(ncols=3, nrows=4, hspace = 0.4)
ttl.set_position([.5, 0.92])



ax1 = plt.subplot(gs[0, 0])
ax1 .hist(cgdConStateErr, bins=10) 
ax1 .set_xlabel("$1-|<\Psi_{RBM}|\Psi_{ED}>|^2$",size = 15)
ax1.set_ylabel("Frequency",size = 15)



ax2 = plt.subplot(gs[0, 1])
ax2.hist(cgdConEngErr, bins=10) 
ax2.set_xlabel("$\Delta E = |E_{RBM}-E_{ED}|$",size = 15)



ax3 = plt.subplot(gs[0, 2])
ax3.hist(cgdConTime, bins=10) 
ax3.set_xlabel("Runtime",size = 15)


ax4 = plt.subplot(gs[1, :])
ax4.set_ylim(-0.0001,0.0001)
ax4.scatter(hisIt,cgdConEngErr) 
ax4 .set_ylabel("$\Delta E = |E_{RBM}-E_{ED}|$", size = 15)


ax5 = plt.subplot(gs[2, :])
ax5.scatter(hisIt,cgdConTime)  
ax5 .set_ylabel("Runtime", size = 15)

ax6 = plt.subplot(gs[3, :])
ax6.scatter(hisIt,cgdConRuns)  
ax6.set_xlabel("Run Number",size = 15)
ax6 .set_ylabel("Number of Attempts", size = 15)
# Out:
# Text(0, 0.5, 'Number of Attempts')

# %%
avEngErr = np.sum(cgdConEngErr)/(len(hisIt))
avStateErr = np.sum(cgdConStateErr)/(len(hisIt))
avRunTime = np.sum(cgdConTime)/(len(hisIt))
relativeErr = np.abs(cgdConEngErr/ActualEng[0])
avRelativeErr = np.sum(relativeErr)/(len(hisIt))
avAttemps = np.sum(cgdConRuns)/(len(hisIt))
print('Average Energy Error: ', avEngErr )
print('Average Ground State Error: ', avStateErr )
print('Average Run Time: ', avRunTime )
print('Average Relative Energy Error: ', avRelativeErr)
print('Average Attemps: ', avAttemps)

cutOff = 0.01
runsCutOff = sum(i>cutOff for i in relativeErr)
prob = (runsCutOff/500)
print("Number of runs below 0.01 relative error:", runsCutOff )
print("Prob of issue:",  f"{prob:.4f}" )
print("Prob of issue two runs:", f"{prob**2:.4f}" )
print("Prob of issue three runs:", f"{prob**3:.5f}" )
# Out:
# Average Energy Error:  5.7086122328575685e-06
# Average Ground State Error:  2.863212971399021e-06
# Average Run Time:  11.929681193828582
# Average Relative Energy Error:  5.9644465435512516e-06
# Average Attemps:  1.15
# Number of runs below 0.01 relative error: 0
# Prob of issue: 0.0000
# Prob of issue two runs: 0.0000
# Prob of issue three runs: 0.00000
