# %%
from qutip import *
import numpy as np
import scipy
import cmath
import matplotlib.pyplot as plt
plt.style.use('seaborn')
import itertools
from numpy.random import seed
from numpy.random import rand
from itertools import product
from scipy.misc import derivative
from scipy import optimize
from functools import wraps
from time import time

# %%
#Wrapper to time functions
def timing(f):
    @wraps(f)
    def wrap(*args, **kw):
        ti = time()
        result = f(*args, **kw)
        tf = time()
        t = tf-ti
        return result, t
    return wrap

# %%
#Make basis and get sz values
def operatorCreation(N):
    #operator definitionis
    si = qeye(2)
    sx = 0.5*sigmax()
    sy = 0.5*sigmay()
    sz = 0.5*sigmaz()

    sx_list = []
    sy_list = []
    sz_list = []
    

    for n in range(N):
        op_list = []
        for m in range(N):
            op_list.append(si)

        op_list[n] = sx
        sx_list.append(tensor(op_list))

        op_list[n] = sy
        sy_list.append(tensor(op_list))

        op_list[n] = sz
        sz_list.append(tensor(op_list))
        
        op_list[n] = si
    id = tensor(op_list)
        
    return sx_list, sy_list, sz_list,id

# %%
#Construct Hamiltonian
def hamiltonian(N,B,A0):
    sx_list = operatorCreation(N)[0]
    sy_list = operatorCreation(N)[1]
    sz_list = operatorCreation(N)[2]
    H = B*sz_list[0] 
    for n in range(N-1):
        H += A0*sz_list[0]*sz_list[n+1] + A0*sx_list[0]*sx_list[n+1] + A0*sy_list[0]*sy_list[n+1]
    return H

# %%
#Check if dengerate
def CheckDegenerate(H):
    estates = H.eigenstates()
    lowState = estates[0][0]
    secLowState = estates[0][1]
    if (abs(lowState-secLowState))<= 1e-10:
        return True
    else:
        return False

# %%
#Get Ground State Energy and Wavefuntion
class GroundState:
    
    def __init__(self, N, B, A0):
        self.hamiltonian = hamiltonian(N, B, A0)
     
    @timing
    def __call__(self):
        #find ground state
        H = self.hamiltonian
        groundState= H.groundstate()
        return groundState[0],groundState[1]

# %%
#Make basis and get sz values
def basisCreation(N):
    sz_list = operatorCreation(N)[2]
    Sbasis = []
    basisState = []
   
    for j in range(2):
        basisState.append(basis(2,j))
    b = itertools.product(basisState,repeat=N)
    basisTensor = list(b)
    #makes Sbasis the correct dimesion of Qobj
    for i in range(2**N):
        c = basisTensor[i][0]
        for j in range(N-1):
            c = tensor(c,basisTensor[i][j+1])
        Sbasis.append(c)

    
    #get sz values for basis states
    sz = np.zeros((2**N,N), dtype = complex)
    a = [[1 for j in range(N)] for i in range(2**N)]
    for i in range(2**N):
        for j in range(N):
            #matrix element <bra|Sz|ket>
            sz[i][j] = sz_list[j].matrix_element(Sbasis[i],Sbasis[i])
    return Sbasis, sz

# %%
#get randomized RBM parameters (between zero and 1)
def ranRBMpar(N,M):
    par = np.random.rand(2*(N+M+N*M))
    return par

# %%
#Function to give RBM wavefuntion
def RBM_ansatz(par,N, M):
    Sbasis = basisCreation(N)[0]
    sz = basisCreation(N)[1]
    #make parmeters complex
    num = N+M+N*M
    parC = np.vectorize(complex)(par[:num],par[num:])
    a = parC[:N]
    b = parC[N:N+M]
    W = parC[N+M:].reshape(M,N)
    expTerm = np.zeros(2**N, dtype = complex)
    coshTerm = np.zeros((M,2**N), dtype = complex)
    hidProduct = np.zeros(2**N, dtype = complex)
    psiMValues = np.zeros(2**N, dtype = complex)
    psiM = 0*Sbasis[0]

    for i in range(2**N):
        for m in range(M):
            coshTerm[m][i] = 2*np.cosh(np.dot(W[m],sz[i]) + b[m])
    hidProduct = np.prod(coshTerm, axis = 0) 
    
    for i in range(2**N):
        expTerm[i] = np.exp(np.dot(a,sz[i]))
        psiMValues[i] = expTerm[i]*hidProduct[i]
        psiM += psiMValues[i]*Sbasis[i]
    psiNorm = psiM.unit()
    return psiNorm

# %%
#Variation Energy Definition
def varEnergy(par,N, M, H):
    psiM = RBM_ansatz(par,N, M)
    E = expect(H,psiM)
    norm = psiM.norm()**2
    Enorm = E/norm
    return Enorm

# %%
#Energy Partials
def gradEnergy(par,N, M,H):
    eps = 0.001
    return optimize.approx_fprime(par,varEnergy,eps, N, M,H)

# %%
#Gradient Descent
class GradDescent:
    
    def __init__(self, N, B, A0):
        H = hamiltonian(N, B, A0)
        isDeg = CheckDegenerate(H)
        if (isDeg == True):
            raise ValueError("Hamiltonian has degenerate ground state")
        else:
            self.hamiltonian = H
     
    @timing 
    def __call__(self, N, M):
        par = ranRBMpar(N,M)
        H = self.hamiltonian
        min = scipy.optimize.fmin_cg(varEnergy,par,args= (N,M,H),gtol = 1e-04, full_output=True, retall = True, disp=True)
        #Ground State
        found_gs = RBM_ansatz(min[0],N, M)
        found_gs = found_gs.unit()
        #Ground State Energy
        found_gsEnergy =varEnergy(min[0], N, M,H)

        return min, found_gs, found_gsEnergy

# %%
#Error Calculation
def err(found_gs,gs,found_gsEnergy,gsEnergy):
    engErr = np.abs(found_gsEnergy-gsEnergy)
    waveFunctionErr = found_gs.dag()*gs
    waveFunctionErr = 1-waveFunctionErr.norm()
    
    return engErr,waveFunctionErr

# %% [markdown]
# # Histogram N=2, M=1

# %%
#Parameter definition 
N= 2
M=1
B = 1
A0 = 1
M1gdResults = [] #gives ground state estimation at each iteration of gd
M1gdState = []
M1gdTime = []

M1edState = []
M1edTime = []

ActualEng = []
M1engErr = []
M1stateErr = []

hisIt = np.arange(100)

# %%
for i in range(len(hisIt)):
    #gradient descent
    gradDescent = GradDescent(N, B, A0)
    gd = gradDescent(N, M)
    M1gdResults.append(gd)
    M1gdState.append(gd[0])
    M1gdTime.append(gd[1])
    
    
    #exact diagonalization 
    groundState = GroundState(N,B,A0)
    ed = groundState()
    M1edState.append(ed[0])
    M1edTime.append(ed[1])
    
    #Error
    gdEngTemp = gd[0][2]
    edEngTemp = ed[0][0]
    ActualEng.append(edEng)
    gdStateTemp = gd[0][1]
    edStateTemp = ed[0][1]
    errTemp = err(gdStateTemp,edStateTemp,gdEngTemp,edEngTemp)
    M1engErr.append(errTemp[0])
    M1stateErr.append(errTemp[1])
# Out:
# Optimization terminated successfully.
#          Current function value: -0.957107
#          Iterations: 42
#          Function evaluations: 1080
#          Gradient evaluations: 90
# Optimization terminated successfully.
#          Current function value: -0.957101
#          Iterations: 27
#          Function evaluations: 732
#          Gradient evaluations: 61
# Optimization terminated successfully.
#          Current function value: -0.957098
#          Iterations: 42
#          Function evaluations: 1044
#          Gradient evaluations: 87
# Optimization terminated successfully.
#          Current function value: -0.957107
#          Iterations: 42
#          Function evaluations: 1008
#          Gradient evaluations: 84
# Optimization terminated successfully.
#          Current function value: -0.957106
#          Iterations: 30
#          Function evaluations: 720
#          Gradient evaluations: 60
# Optimization terminated successfully.
#          Current function value: -0.957107
#          Iterations: 23
#          Function evaluations: 564
#          Gradient evaluations: 47
# Optimization terminated successfully.
#          Current function value: -0.957105
#          Iterations: 29
#          Function evaluations: 708
#          Gradient evaluations: 59
# Optimization terminated successfully.
#          Current function value: -0.957095
#          Iterations: 61
#          Function evaluations: 1248
#          Gradient evaluations: 104
# Optimization terminated successfully.
#          Current function value: -0.957107
#          Iterations: 44
#          Function evaluations: 1032
#          Gradient evaluations: 86
# Optimization terminated successfully.
#          Current function value: -0.957105
#          Iterations: 31
#          Function evaluations: 1236
#          Gradient evaluations: 103
# Optimization terminated successfully.
#          Current function value: -0.957072
#          Iterations: 28
#          Function evaluations: 792
#          Gradient evaluations: 66
# Optimization terminated successfully.
#          Current function value: -0.749928
#          Iterations: 7
#          Function evaluations: 300
#          Gradient evaluations: 25
# Optimization terminated successfully.
#          Current function value: -0.957093
#          Iterations: 32
#          Function evaluations: 806
#          Gradient evaluations: 67
# Optimization terminated successfully.
#          Current function value: -0.957073
#          Iterations: 41
#          Function evaluations: 1080
#          Gradient evaluations: 90
# Optimization terminated successfully.
#          Current function value: -0.749966
#          Iterations: 4
#          Function evaluations: 228
#          Gradient evaluations: 19
# Optimization terminated successfully.
#          Current function value: -0.957100
#          Iterations: 37
#          Function evaluations: 1008
#          Gradient evaluations: 84
# Optimization terminated successfully.
#          Current function value: -0.957084
#          Iterations: 21
#          Function evaluations: 732
#          Gradient evaluations: 61
# Optimization terminated successfully.
#          Current function value: -0.749942
#          Iterations: 3
#          Function evaluations: 192
#          Gradient evaluations: 16
# Optimization terminated successfully.
#          Current function value: -0.250001
#          Iterations: 2
#          Function evaluations: 96
#          Gradient evaluations: 8
# Optimization terminated successfully.
#          Current function value: -0.957097
#          Iterations: 37
#          Function evaluations: 792
#          Gradient evaluations: 66
# Optimization terminated successfully.
#          Current function value: -0.957103
#          Iterations: 26
#          Function evaluations: 732
#          Gradient evaluations: 61
# Optimization terminated successfully.
#          Current function value: -0.957107
#          Iterations: 16
#          Function evaluations: 516
#          Gradient evaluations: 43
# Optimization terminated successfully.
#          Current function value: -0.957107
#          Iterations: 61
#          Function evaluations: 1416
#          Gradient evaluations: 118
# Optimization terminated successfully.
#          Current function value: -0.957063
#          Iterations: 60
#          Function evaluations: 1764
#          Gradient evaluations: 147
# Optimization terminated successfully.
#          Current function value: -0.749960
#          Iterations: 9
#          Function evaluations: 384
#          Gradient evaluations: 32
# Optimization terminated successfully.
#          Current function value: -0.957100
#          Iterations: 56
#          Function evaluations: 1356
#          Gradient evaluations: 113
# Optimization terminated successfully.
#          Current function value: -0.957106
#          Iterations: 24
#          Function evaluations: 912
#          Gradient evaluations: 76
# Optimization terminated successfully.
#          Current function value: -0.749968
#          Iterations: 5
#          Function evaluations: 300
#          Gradient evaluations: 25
# Optimization terminated successfully.
#          Current function value: -0.957095
#          Iterations: 39
#          Function evaluations: 1092
#          Gradient evaluations: 91
# Optimization terminated successfully.
#          Current function value: -0.957106
#          Iterations: 28
#          Function evaluations: 828
#          Gradient evaluations: 69
# Optimization terminated successfully.
#          Current function value: -0.749956
#          Iterations: 4
#          Function evaluations: 168
#          Gradient evaluations: 14
# Optimization terminated successfully.
#          Current function value: -0.749956
#          Iterations: 6
#          Function evaluations: 300
#          Gradient evaluations: 25
# Optimization terminated successfully.
#          Current function value: -0.749962
#          Iterations: 6
#          Function evaluations: 276
#          Gradient evaluations: 23
# Optimization terminated successfully.
#          Current function value: -0.957102
#          Iterations: 44
#          Function evaluations: 1236
#          Gradient evaluations: 103
# Optimization terminated successfully.
#          Current function value: -0.957099
#          Iterations: 34
#          Function evaluations: 804
#          Gradient evaluations: 67
# Optimization terminated successfully.
#          Current function value: -0.957106
#          Iterations: 30
#          Function evaluations: 636
#          Gradient evaluations: 53
# Optimization terminated successfully.
#          Current function value: -0.957107
#          Iterations: 24
#          Function evaluations: 624
#          Gradient evaluations: 52
# Optimization terminated successfully.
#          Current function value: -0.957087
#          Iterations: 36
#          Function evaluations: 816
#          Gradient evaluations: 68
# Optimization terminated successfully.
#          Current function value: -0.957097
#          Iterations: 35
#          Function evaluations: 1188
#          Gradient evaluations: 99
# Optimization terminated successfully.
#          Current function value: -0.957105
#          Iterations: 41
#          Function evaluations: 900
#          Gradient evaluations: 75
# Optimization terminated successfully.
#          Current function value: -0.957101
#          Iterations: 47
#          Function evaluations: 1104
#          Gradient evaluations: 92
# Optimization terminated successfully.
#          Current function value: -0.957074
#          Iterations: 24
#          Function evaluations: 900
#          Gradient evaluations: 75
# Optimization terminated successfully.
#          Current function value: -0.957080
#          Iterations: 59
#          Function evaluations: 1536
#          Gradient evaluations: 128
# Optimization terminated successfully.
#          Current function value: -0.957087
#          Iterations: 40
#          Function evaluations: 1176
#          Gradient evaluations: 98
# Optimization terminated successfully.
#          Current function value: -0.957106
#          Iterations: 28
#          Function evaluations: 708
#          Gradient evaluations: 59
# Optimization terminated successfully.
#          Current function value: -0.957107
#          Iterations: 45
#          Function evaluations: 1224
#          Gradient evaluations: 102
# Optimization terminated successfully.
#          Current function value: -0.957106
#          Iterations: 49
#          Function evaluations: 1236
#          Gradient evaluations: 103
# Optimization terminated successfully.
#          Current function value: -0.749958
#          Iterations: 6
#          Function evaluations: 228
#          Gradient evaluations: 19
# Optimization terminated successfully.
#          Current function value: -0.957091
#          Iterations: 29
#          Function evaluations: 972
#          Gradient evaluations: 81
# Optimization terminated successfully.
#          Current function value: -0.957104
#          Iterations: 34
#          Function evaluations: 852
#          Gradient evaluations: 71
# Optimization terminated successfully.
#          Current function value: -0.957069
#          Iterations: 28
#          Function evaluations: 936
#          Gradient evaluations: 78
# Optimization terminated successfully.
#          Current function value: -0.249989
#          Iterations: 5
#          Function evaluations: 288
#          Gradient evaluations: 24
# Optimization terminated successfully.
#          Current function value: -0.957059
#          Iterations: 25
#          Function evaluations: 1092
#          Gradient evaluations: 91
# Optimization terminated successfully.
#          Current function value: -0.957097
#          Iterations: 37
#          Function evaluations: 1128
#          Gradient evaluations: 94
# Optimization terminated successfully.
#          Current function value: -0.749995
#          Iterations: 4
#          Function evaluations: 216
#          Gradient evaluations: 18
# Optimization terminated successfully.
#          Current function value: -0.957107
#          Iterations: 20
#          Function evaluations: 588
#          Gradient evaluations: 49
# Optimization terminated successfully.
#          Current function value: -0.749934
#          Iterations: 7
#          Function evaluations: 336
#          Gradient evaluations: 28
# Optimization terminated successfully.
#          Current function value: -0.957104
#          Iterations: 31
#          Function evaluations: 1044
#          Gradient evaluations: 87
# Optimization terminated successfully.
#          Current function value: -0.957039
#          Iterations: 20
#          Function evaluations: 624
#          Gradient evaluations: 52
# Optimization terminated successfully.
#          Current function value: -0.749989
#          Iterations: 7
#          Function evaluations: 348
#          Gradient evaluations: 29
# Optimization terminated successfully.
#          Current function value: -0.957107
#          Iterations: 36
#          Function evaluations: 972
#          Gradient evaluations: 81
# Optimization terminated successfully.
#          Current function value: -0.957107
#          Iterations: 36
#          Function evaluations: 708
#          Gradient evaluations: 59
# Optimization terminated successfully.
#          Current function value: -0.957107
#          Iterations: 15
#          Function evaluations: 312
#          Gradient evaluations: 26
# Optimization terminated successfully.
#          Current function value: -0.957093
#          Iterations: 54
#          Function evaluations: 1512
#          Gradient evaluations: 126
# Optimization terminated successfully.
#          Current function value: -0.957107
#          Iterations: 38
#          Function evaluations: 864
#          Gradient evaluations: 72
# Optimization terminated successfully.
#          Current function value: -0.749947
#          Iterations: 6
#          Function evaluations: 276
#          Gradient evaluations: 23
# Optimization terminated successfully.
#          Current function value: -0.749956
#          Iterations: 4
#          Function evaluations: 192
#          Gradient evaluations: 16
# Optimization terminated successfully.
#          Current function value: -0.749945
#          Iterations: 2
#          Function evaluations: 96
#          Gradient evaluations: 8
# Optimization terminated successfully.
#          Current function value: -0.957092
#          Iterations: 26
#          Function evaluations: 744
#          Gradient evaluations: 62
# Optimization terminated successfully.
#          Current function value: -0.957102
#          Iterations: 39
#          Function evaluations: 1392
#          Gradient evaluations: 116
# Optimization terminated successfully.
#          Current function value: -0.749994
#          Iterations: 4
#          Function evaluations: 228
#          Gradient evaluations: 19
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: -0.956900
#          Iterations: 89
#          Function evaluations: 3120
#          Gradient evaluations: 259
# Optimization terminated successfully.
#          Current function value: -0.957107
#          Iterations: 17
#          Function evaluations: 432
#          Gradient evaluations: 36
# Optimization terminated successfully.
#          Current function value: -0.957101
#          Iterations: 30
#          Function evaluations: 912
#          Gradient evaluations: 76
# Optimization terminated successfully.
#          Current function value: -0.957100
#          Iterations: 67
#          Function evaluations: 1500
#          Gradient evaluations: 125
# Optimization terminated successfully.
#          Current function value: -0.750010
#          Iterations: 5
#          Function evaluations: 240
#          Gradient evaluations: 20
# Optimization terminated successfully.
#          Current function value: -0.957106
#          Iterations: 26
#          Function evaluations: 732
#          Gradient evaluations: 61
# Optimization terminated successfully.
#          Current function value: -0.957092
#          Iterations: 26
#          Function evaluations: 768
#          Gradient evaluations: 64
# Optimization terminated successfully.
#          Current function value: -0.749988
#          Iterations: 4
#          Function evaluations: 228
#          Gradient evaluations: 19
# Optimization terminated successfully.
#          Current function value: -0.957106
#          Iterations: 33
#          Function evaluations: 792
#          Gradient evaluations: 66
# Optimization terminated successfully.
#          Current function value: -0.957097
#          Iterations: 32
#          Function evaluations: 876
#          Gradient evaluations: 73
# Optimization terminated successfully.
#          Current function value: -0.957106
#          Iterations: 29
#          Function evaluations: 576
#          Gradient evaluations: 48
# Optimization terminated successfully.
#          Current function value: -0.957107
#          Iterations: 17
#          Function evaluations: 312
#          Gradient evaluations: 26
# Optimization terminated successfully.
#          Current function value: -0.957107
#          Iterations: 32
#          Function evaluations: 708
#          Gradient evaluations: 59
# Optimization terminated successfully.
#          Current function value: -0.957106
#          Iterations: 51
#          Function evaluations: 1212
#          Gradient evaluations: 101
# Optimization terminated successfully.
#          Current function value: -0.957106
#          Iterations: 47
#          Function evaluations: 1044
#          Gradient evaluations: 87
# Optimization terminated successfully.
#          Current function value: -0.957089
#          Iterations: 28
#          Function evaluations: 852
#          Gradient evaluations: 71
# Optimization terminated successfully.
#          Current function value: -0.957046
#          Iterations: 33
#          Function evaluations: 1056
#          Gradient evaluations: 88
# Optimization terminated successfully.
#          Current function value: -0.957100
#          Iterations: 30
#          Function evaluations: 840
#          Gradient evaluations: 70
# Optimization terminated successfully.
#          Current function value: -0.957093
#          Iterations: 32
#          Function evaluations: 864
#          Gradient evaluations: 72
# Optimization terminated successfully.
#          Current function value: -0.957107
#          Iterations: 43
#          Function evaluations: 1080
#          Gradient evaluations: 90
# Optimization terminated successfully.
#          Current function value: -0.749968
#          Iterations: 7
#          Function evaluations: 372
#          Gradient evaluations: 31
# Optimization terminated successfully.
#          Current function value: -0.957106
#          Iterations: 32
#          Function evaluations: 720
#          Gradient evaluations: 60
# Optimization terminated successfully.
#          Current function value: -0.957106
#          Iterations: 29
#          Function evaluations: 660
#          Gradient evaluations: 55
# Optimization terminated successfully.
#          Current function value: -0.957105
#          Iterations: 50
#          Function evaluations: 1176
#          Gradient evaluations: 98
# Optimization terminated successfully.
#          Current function value: -0.957103
#          Iterations: 17
#          Function evaluations: 612
#          Gradient evaluations: 51
# Optimization terminated successfully.
#          Current function value: -0.957107
#          Iterations: 22
#          Function evaluations: 528
#          Gradient evaluations: 44
# Optimization terminated successfully.
#          Current function value: -0.957106
#          Iterations: 33
#          Function evaluations: 1152
#          Gradient evaluations: 96
# Optimization terminated successfully.
#          Current function value: -0.957104
#          Iterations: 22
#          Function evaluations: 660
#          Gradient evaluations: 55
# Optimization terminated successfully.
#          Current function value: -0.957043
#          Iterations: 59
#          Function evaluations: 1572
#          Gradient evaluations: 131

# %%
plt.figure(figsize=(10,10))
ttl = plt.suptitle("N = 2, M = 1 \n Wavefunction Error Histogram",size =20)
ttl.set_position([.5, 0.95])
plt.hist(M1stateErr, bins=50) 
plt.xlabel("Wavefunction Error",size = 15)
plt.ylabel("Frequency", size = 15)
plt.show()

# %%
plt.figure(figsize=(10,10))
ttl = plt.suptitle("N = 2, M = 1 \n Runtime Histogram",size =20)
ttl.set_position([.5, 0.95])
plt.hist(M1gdTime, bins=50) 
plt.xlabel("Runtime",size = 15)
plt.ylabel("Frequency", size = 15)
plt.show()

# %%
plt.figure(figsize=(10,10))
ttl = plt.suptitle("N = 2, M = 1 ",size =20)
ttl.set_position([.5, 0.92])
ax1 = plt.subplot(2,1,1)

color = 'tab:red'
ax1.set_xlabel('N Value')
ax1.set_ylabel('Wavefunction Error', color=color)
ax1.scatter(hisIt, M1stateErr,color=color)
ax1.tick_params(axis='y', labelcolor=color)

ax2 = ax1.twinx()  

color = 'tab:blue'
ax2.set_ylabel('Runtime', color=color)  
ax2.scatter(hisIt, M1gdTime, color=color)
ax2.tick_params(axis='y', labelcolor=color)

# %% [markdown]
# # Histogram N=2, M=2

# %%
#Parameter definition 
N= 2
M=2
B = 1
A0 = 1
M2gdResults = [] #gives ground state estimation at each iteration of gd
M2gdState = []
M2gdTime = []

M2edState = []
M2edTime = []

ActualEng = []
M2engErr = []
M2stateErr = []

M2hisIt = np.arange(100)

# %%
for i in range(len(hisIt)):
    #gradient descent
    gradDescent = GradDescent(N, B, A0)
    gd = gradDescent(N, M)
    M2gdResults.append(gd)
    M2gdState.append(gd[0])
    M2gdTime.append(gd[1])
    
    
    #exact diagonalization 
    groundState = GroundState(N,B,A0)
    ed = groundState()
    M2edState.append(ed[0])
    M2edTime.append(ed[1])
    
    #Error
    gdEngTemp = gd[0][2]
    edEngTemp = ed[0][0]
    ActualEng.append(edEng)
    gdStateTemp = gd[0][1]
    edStateTemp = ed[0][1]
    errTemp = err(gdStateTemp,edStateTemp,gdEngTemp,edEngTemp)
    M2engErr.append(errTemp[0])
    M2stateErr.append(errTemp[1])
# Out:
# Optimization terminated successfully.
#          Current function value: -0.957107
#          Iterations: 18
#          Function evaluations: 828
#          Gradient evaluations: 46
# Optimization terminated successfully.
#          Current function value: -0.957097
#          Iterations: 79
#          Function evaluations: 3042
#          Gradient evaluations: 169
# Optimization terminated successfully.
#          Current function value: -0.957105
#          Iterations: 24
#          Function evaluations: 1206
#          Gradient evaluations: 67
# Optimization terminated successfully.
#          Current function value: -0.957100
#          Iterations: 55
#          Function evaluations: 2484
#          Gradient evaluations: 138
# Optimization terminated successfully.
#          Current function value: -0.957107
#          Iterations: 15
#          Function evaluations: 450
#          Gradient evaluations: 25
# Optimization terminated successfully.
#          Current function value: -0.957107
#          Iterations: 20
#          Function evaluations: 738
#          Gradient evaluations: 41
# Optimization terminated successfully.
#          Current function value: -0.749994
#          Iterations: 7
#          Function evaluations: 468
#          Gradient evaluations: 26
# Optimization terminated successfully.
#          Current function value: -0.957107
#          Iterations: 45
#          Function evaluations: 1764
#          Gradient evaluations: 98
# Optimization terminated successfully.
#          Current function value: -0.957105
#          Iterations: 37
#          Function evaluations: 1674
#          Gradient evaluations: 93
# Optimization terminated successfully.
#          Current function value: -0.957091
#          Iterations: 35
#          Function evaluations: 1782
#          Gradient evaluations: 99
# Optimization terminated successfully.
#          Current function value: -0.957107
#          Iterations: 46
#          Function evaluations: 1602
#          Gradient evaluations: 89
# Optimization terminated successfully.
#          Current function value: -0.957106
#          Iterations: 96
#          Function evaluations: 3330
#          Gradient evaluations: 185
# Optimization terminated successfully.
#          Current function value: -0.957101
#          Iterations: 99
#          Function evaluations: 3132
#          Gradient evaluations: 174
# Optimization terminated successfully.
#          Current function value: -0.957051
#          Iterations: 64
#          Function evaluations: 2034
#          Gradient evaluations: 113
# Optimization terminated successfully.
#          Current function value: -0.957107
#          Iterations: 18
#          Function evaluations: 702
#          Gradient evaluations: 39
# Optimization terminated successfully.
#          Current function value: -0.957099
#          Iterations: 22
#          Function evaluations: 810
#          Gradient evaluations: 45
# Optimization terminated successfully.
#          Current function value: -0.957107
#          Iterations: 39
#          Function evaluations: 1386
#          Gradient evaluations: 77
# Optimization terminated successfully.
#          Current function value: -0.957101
#          Iterations: 70
#          Function evaluations: 2520
#          Gradient evaluations: 140
# Optimization terminated successfully.
#          Current function value: -0.749969
#          Iterations: 5
#          Function evaluations: 342
#          Gradient evaluations: 19
# Optimization terminated successfully.
#          Current function value: -0.957107
#          Iterations: 21
#          Function evaluations: 882
#          Gradient evaluations: 49
# Optimization terminated successfully.
#          Current function value: -0.749958
#          Iterations: 6
#          Function evaluations: 432
#          Gradient evaluations: 24
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: -0.957007
#          Iterations: 125
#          Function evaluations: 7626
#          Gradient evaluations: 423
# Optimization terminated successfully.
#          Current function value: -0.957105
#          Iterations: 29
#          Function evaluations: 1062
#          Gradient evaluations: 59
# Optimization terminated successfully.
#          Current function value: -0.957105
#          Iterations: 20
#          Function evaluations: 720
#          Gradient evaluations: 40
# Optimization terminated successfully.
#          Current function value: -0.749980
#          Iterations: 7
#          Function evaluations: 450
#          Gradient evaluations: 25
# Optimization terminated successfully.
#          Current function value: -0.957107
#          Iterations: 22
#          Function evaluations: 738
#          Gradient evaluations: 41
# Optimization terminated successfully.
#          Current function value: -0.957106
#          Iterations: 34
#          Function evaluations: 1242
#          Gradient evaluations: 69
# Optimization terminated successfully.
#          Current function value: -0.957090
#          Iterations: 26
#          Function evaluations: 1332
#          Gradient evaluations: 74
# Optimization terminated successfully.
#          Current function value: -0.957106
#          Iterations: 19
#          Function evaluations: 630
#          Gradient evaluations: 35
# Optimization terminated successfully.
#          Current function value: -0.957106
#          Iterations: 23
#          Function evaluations: 882
#          Gradient evaluations: 49
# Optimization terminated successfully.
#          Current function value: -0.957107
#          Iterations: 26
#          Function evaluations: 918
#          Gradient evaluations: 51
# Optimization terminated successfully.
#          Current function value: -0.957092
#          Iterations: 22
#          Function evaluations: 1170
#          Gradient evaluations: 65
# Optimization terminated successfully.
#          Current function value: -0.957104
#          Iterations: 25
#          Function evaluations: 936
#          Gradient evaluations: 52
# Optimization terminated successfully.
#          Current function value: -0.957107
#          Iterations: 21
#          Function evaluations: 702
#          Gradient evaluations: 39
# Optimization terminated successfully.
#          Current function value: -0.749972
#          Iterations: 5
#          Function evaluations: 450
#          Gradient evaluations: 25
# Optimization terminated successfully.
#          Current function value: -0.750048
#          Iterations: 4
#          Function evaluations: 378
#          Gradient evaluations: 21
# Optimization terminated successfully.
#          Current function value: -0.957107
#          Iterations: 31
#          Function evaluations: 1062
#          Gradient evaluations: 59
# Optimization terminated successfully.
#          Current function value: -0.957086
#          Iterations: 73
#          Function evaluations: 3042
#          Gradient evaluations: 169
# Optimization terminated successfully.
#          Current function value: -0.957098
#          Iterations: 41
#          Function evaluations: 1278
#          Gradient evaluations: 71
# Optimization terminated successfully.
#          Current function value: -0.957094
#          Iterations: 36
#          Function evaluations: 1548
#          Gradient evaluations: 86
# Optimization terminated successfully.
#          Current function value: -0.957106
#          Iterations: 21
#          Function evaluations: 828
#          Gradient evaluations: 46
# Optimization terminated successfully.
#          Current function value: -0.957105
#          Iterations: 66
#          Function evaluations: 2736
#          Gradient evaluations: 152
# Optimization terminated successfully.
#          Current function value: -0.957106
#          Iterations: 42
#          Function evaluations: 1728
#          Gradient evaluations: 96
# Optimization terminated successfully.
#          Current function value: -0.957107
#          Iterations: 24
#          Function evaluations: 1080
#          Gradient evaluations: 60
# Optimization terminated successfully.
#          Current function value: -0.957107
#          Iterations: 16
#          Function evaluations: 468
#          Gradient evaluations: 26
# Optimization terminated successfully.
#          Current function value: -0.957103
#          Iterations: 132
#          Function evaluations: 4536
#          Gradient evaluations: 252
# Optimization terminated successfully.
#          Current function value: -0.957106
#          Iterations: 30
#          Function evaluations: 1494
#          Gradient evaluations: 83
# Optimization terminated successfully.
#          Current function value: -0.957097
#          Iterations: 33
#          Function evaluations: 990
#          Gradient evaluations: 55
# Optimization terminated successfully.
#          Current function value: -0.957107
#          Iterations: 37
#          Function evaluations: 1386
#          Gradient evaluations: 77
# Optimization terminated successfully.
#          Current function value: -0.957107
#          Iterations: 15
#          Function evaluations: 666
#          Gradient evaluations: 37
# Optimization terminated successfully.
#          Current function value: -0.957106
#          Iterations: 21
#          Function evaluations: 882
#          Gradient evaluations: 49
# Optimization terminated successfully.
#          Current function value: -0.957101
#          Iterations: 90
#          Function evaluations: 2664
#          Gradient evaluations: 148
# Optimization terminated successfully.
#          Current function value: -0.957104
#          Iterations: 68
#          Function evaluations: 2754
#          Gradient evaluations: 153
# Optimization terminated successfully.
#          Current function value: -0.957106
#          Iterations: 23
#          Function evaluations: 846
#          Gradient evaluations: 47
# Optimization terminated successfully.
#          Current function value: -0.957107
#          Iterations: 46
#          Function evaluations: 1728
#          Gradient evaluations: 96
# Optimization terminated successfully.
#          Current function value: -0.957099
#          Iterations: 50
#          Function evaluations: 2088
#          Gradient evaluations: 116
# Optimization terminated successfully.
#          Current function value: -0.957107
#          Iterations: 38
#          Function evaluations: 1296
#          Gradient evaluations: 72
# Optimization terminated successfully.
#          Current function value: -0.957106
#          Iterations: 63
#          Function evaluations: 2394
#          Gradient evaluations: 133
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: -0.957059
#          Iterations: 70
#          Function evaluations: 4155
#          Gradient evaluations: 230
# Optimization terminated successfully.
#          Current function value: -0.749959
#          Iterations: 7
#          Function evaluations: 468
#          Gradient evaluations: 26
# Optimization terminated successfully.
#          Current function value: -0.957107
#          Iterations: 26
#          Function evaluations: 1008
#          Gradient evaluations: 56
# Optimization terminated successfully.
#          Current function value: -0.957107
#          Iterations: 29
#          Function evaluations: 1062
#          Gradient evaluations: 59
# Optimization terminated successfully.
#          Current function value: -0.957107
#          Iterations: 20
#          Function evaluations: 666
#          Gradient evaluations: 37
# Optimization terminated successfully.
#          Current function value: -0.957106
#          Iterations: 34
#          Function evaluations: 1350
#          Gradient evaluations: 75
# Optimization terminated successfully.
#          Current function value: -0.957083
#          Iterations: 32
#          Function evaluations: 1602
#          Gradient evaluations: 89
# Optimization terminated successfully.
#          Current function value: -0.957107
#          Iterations: 18
#          Function evaluations: 738
#          Gradient evaluations: 41
# Optimization terminated successfully.
#          Current function value: -0.957107
#          Iterations: 22
#          Function evaluations: 846
#          Gradient evaluations: 47
# Optimization terminated successfully.
#          Current function value: -0.957106
#          Iterations: 19
#          Function evaluations: 792
#          Gradient evaluations: 44
# Optimization terminated successfully.
#          Current function value: -0.957095
#          Iterations: 28
#          Function evaluations: 1566
#          Gradient evaluations: 87
# Optimization terminated successfully.
#          Current function value: -0.957105
#          Iterations: 31
#          Function evaluations: 1746
#          Gradient evaluations: 97
# Optimization terminated successfully.
#          Current function value: -0.957107
#          Iterations: 39
#          Function evaluations: 1350
#          Gradient evaluations: 75
# Optimization terminated successfully.
#          Current function value: -0.957100
#          Iterations: 29
#          Function evaluations: 1152
#          Gradient evaluations: 64
# Optimization terminated successfully.
#          Current function value: -0.957105
#          Iterations: 44
#          Function evaluations: 1422
#          Gradient evaluations: 79
# Optimization terminated successfully.
#          Current function value: -0.957107
#          Iterations: 19
#          Function evaluations: 684
#          Gradient evaluations: 38
# Optimization terminated successfully.
#          Current function value: -0.957105
#          Iterations: 38
#          Function evaluations: 1422
#          Gradient evaluations: 79
# Optimization terminated successfully.
#          Current function value: -0.957107
#          Iterations: 61
#          Function evaluations: 2358
#          Gradient evaluations: 131
# Optimization terminated successfully.
#          Current function value: -0.749989
#          Iterations: 7
#          Function evaluations: 558
#          Gradient evaluations: 31
# Optimization terminated successfully.
#          Current function value: -0.957105
#          Iterations: 29
#          Function evaluations: 1152
#          Gradient evaluations: 64
# Optimization terminated successfully.
#          Current function value: -0.957086
#          Iterations: 24
#          Function evaluations: 954
#          Gradient evaluations: 53
# Optimization terminated successfully.
#          Current function value: -0.957106
#          Iterations: 55
#          Function evaluations: 1962
#          Gradient evaluations: 109
# Optimization terminated successfully.
#          Current function value: -0.957106
#          Iterations: 47
#          Function evaluations: 1530
#          Gradient evaluations: 85
# Optimization terminated successfully.
#          Current function value: -0.957099
#          Iterations: 45
#          Function evaluations: 1458
#          Gradient evaluations: 81
# Optimization terminated successfully.
#          Current function value: -0.957105
#          Iterations: 89
#          Function evaluations: 2628
#          Gradient evaluations: 146
# Optimization terminated successfully.
#          Current function value: -0.957107
#          Iterations: 28
#          Function evaluations: 1152
#          Gradient evaluations: 64
# Optimization terminated successfully.
#          Current function value: -0.957107
#          Iterations: 51
#          Function evaluations: 1836
#          Gradient evaluations: 102
# Optimization terminated successfully.
#          Current function value: -0.749960
#          Iterations: 10
#          Function evaluations: 612
#          Gradient evaluations: 34
# Optimization terminated successfully.
#          Current function value: -0.957107
#          Iterations: 31
#          Function evaluations: 1116
#          Gradient evaluations: 62
# Optimization terminated successfully.
#          Current function value: -0.957102
#          Iterations: 26
#          Function evaluations: 1728
#          Gradient evaluations: 96
# Optimization terminated successfully.
#          Current function value: -0.957091
#          Iterations: 42
#          Function evaluations: 1980
#          Gradient evaluations: 110
# Optimization terminated successfully.
#          Current function value: -0.750001
#          Iterations: 5
#          Function evaluations: 288
#          Gradient evaluations: 16
# Optimization terminated successfully.
#          Current function value: -0.957106
#          Iterations: 39
#          Function evaluations: 1764
#          Gradient evaluations: 98
# Optimization terminated successfully.
#          Current function value: -0.957106
#          Iterations: 37
#          Function evaluations: 1422
#          Gradient evaluations: 79
# Optimization terminated successfully.
#          Current function value: -0.749991
#          Iterations: 6
#          Function evaluations: 378
#          Gradient evaluations: 21
# Optimization terminated successfully.
#          Current function value: -0.957107
#          Iterations: 39
#          Function evaluations: 1278
#          Gradient evaluations: 71
# Optimization terminated successfully.
#          Current function value: -0.957107
#          Iterations: 15
#          Function evaluations: 594
#          Gradient evaluations: 33
# Optimization terminated successfully.
#          Current function value: -0.957107
#          Iterations: 14
#          Function evaluations: 522
#          Gradient evaluations: 29
# Optimization terminated successfully.
#          Current function value: -0.750011
#          Iterations: 4
#          Function evaluations: 324
#          Gradient evaluations: 18
# Optimization terminated successfully.
#          Current function value: -0.957107
#          Iterations: 18
#          Function evaluations: 738
#          Gradient evaluations: 41
# Optimization terminated successfully.
#          Current function value: -0.957107
#          Iterations: 22
#          Function evaluations: 792
#          Gradient evaluations: 44
# Optimization terminated successfully.
#          Current function value: -0.957107
#          Iterations: 13
#          Function evaluations: 324
#          Gradient evaluations: 18

# %%
plt.figure(figsize=(10,10))
ttl = plt.suptitle("N = 2, M = 2 \n Wavefunction Error Histogram",size =20)
ttl.set_position([.5, 0.95])
plt.hist(M2stateErr, bins=50) 
plt.xlabel("Wavefunction Error",size = 15)
plt.ylabel("Frequency", size = 15)
plt.show()

# %%
plt.figure(figsize=(10,10))
ttl = plt.suptitle("N = 2, M = 2 \n Runtime Histogram",size =20)
ttl.set_position([.5, 0.95])
plt.hist(M2gdTime, bins=50) 
plt.xlabel("Runtime",size = 15)
plt.ylabel("Frequency", size = 15)
plt.show()

# %%
plt.figure(figsize=(10,10))
ttl = plt.suptitle("N = 2, M = 2 ",size =20)
ttl.set_position([.5, 0.92])
ax1 = plt.subplot(2,1,1)

color = 'tab:red'
ax1.set_xlabel('Run Number')
ax1.set_ylabel('Wavefunction Error', color=color)
ax1.scatter(hisIt, M2stateErr,color=color)
ax1.tick_params(axis='y', labelcolor=color)

ax2 = ax1.twinx()  

color = 'tab:blue'
ax2.set_ylabel('Runtime', color=color)  
ax2.scatter(hisIt, M2gdTime, color=color)
ax2.tick_params(axis='y', labelcolor=color)

# %% [markdown]
# # Histogram N=3, M=1

# %%
#Parameter definition 
N= 3
M=1
B = 1
A0 = 1
N3M1gdResults = [] #gives ground state estimation at each iteration of gd
N3M1gdState = []
N3M1gdTime = []

N3M1edState = []
N3M1edTime = []

ActualEng = []
N3M1engErr = []
N3M1stateErr = []

hisIt = np.arange(100)

# %%
for i in range(len(hisIt)):
    #gradient descent
    gradDescent = GradDescent(N, B, A0)
    gd = gradDescent(N, M)
    N3M1gdResults.append(gd)
    N3M1gdState.append(gd[0])
    N3M1gdTime.append(gd[1])
    
    
    #exact diagonalization 
    groundState = GroundState(N,B,A0)
    ed = groundState()
    N3M1edState.append(ed[0])
    N3M1edTime.append(ed[1])
    
    #Error
    gdEngTemp = gd[0][2]
    edEngTemp = ed[0][0]
    ActualEng.append(edEng)
    gdStateTemp = gd[0][1]
    edStateTemp = ed[0][1]
    errTemp = err(gdStateTemp,edStateTemp,gdEngTemp,edEngTemp)
    N3M1engErr.append(errTemp[0])
    N3M1stateErr.append(errTemp[1])
# Out:
# Optimization terminated successfully.
#          Current function value: -1.280732
#          Iterations: 190
#          Function evaluations: 6880
#          Gradient evaluations: 430
# Optimization terminated successfully.
#          Current function value: -1.280681
#          Iterations: 223
#          Function evaluations: 8848
#          Gradient evaluations: 553
# Optimization terminated successfully.
#          Current function value: -0.999968
#          Iterations: 7
#          Function evaluations: 416
#          Gradient evaluations: 26
# Optimization terminated successfully.
#          Current function value: -0.499975
#          Iterations: 3
#          Function evaluations: 240
#          Gradient evaluations: 15
# Optimization terminated successfully.
#          Current function value: -0.999918
#          Iterations: 7
#          Function evaluations: 416
#          Gradient evaluations: 26
# Optimization terminated successfully.
#          Current function value: -0.999954
#          Iterations: 7
#          Function evaluations: 512
#          Gradient evaluations: 32
# Optimization terminated successfully.
#          Current function value: -1.280722
#          Iterations: 234
#          Function evaluations: 9184
#          Gradient evaluations: 574
# Optimization terminated successfully.
#          Current function value: -0.999998
#          Iterations: 8
#          Function evaluations: 496
#          Gradient evaluations: 31
# Optimization terminated successfully.
#          Current function value: -1.280667
#          Iterations: 199
#          Function evaluations: 8576
#          Gradient evaluations: 536
# Optimization terminated successfully.
#          Current function value: -0.999927
#          Iterations: 5
#          Function evaluations: 304
#          Gradient evaluations: 19
# Optimization terminated successfully.
#          Current function value: -1.280736
#          Iterations: 194
#          Function evaluations: 7216
#          Gradient evaluations: 451
# Optimization terminated successfully.
#          Current function value: -0.999929
#          Iterations: 7
#          Function evaluations: 416
#          Gradient evaluations: 26
# Optimization terminated successfully.
#          Current function value: -1.280696
#          Iterations: 206
#          Function evaluations: 7728
#          Gradient evaluations: 483
# Optimization terminated successfully.
#          Current function value: -1.280709
#          Iterations: 185
#          Function evaluations: 7744
#          Gradient evaluations: 484
# Optimization terminated successfully.
#          Current function value: -0.999936
#          Iterations: 9
#          Function evaluations: 512
#          Gradient evaluations: 32
# Optimization terminated successfully.
#          Current function value: -1.280711
#          Iterations: 225
#          Function evaluations: 8848
#          Gradient evaluations: 553
# Optimization terminated successfully.
#          Current function value: -1.151404
#          Iterations: 61
#          Function evaluations: 2368
#          Gradient evaluations: 148
# Optimization terminated successfully.
#          Current function value: -0.999947
#          Iterations: 8
#          Function evaluations: 496
#          Gradient evaluations: 31
# Optimization terminated successfully.
#          Current function value: -1.280721
#          Iterations: 304
#          Function evaluations: 12496
#          Gradient evaluations: 781
# Optimization terminated successfully.
#          Current function value: -1.280747
#          Iterations: 177
#          Function evaluations: 6416
#          Gradient evaluations: 401
# Optimization terminated successfully.
#          Current function value: -0.499983
#          Iterations: 8
#          Function evaluations: 592
#          Gradient evaluations: 37
# Optimization terminated successfully.
#          Current function value: -1.151375
#          Iterations: 34
#          Function evaluations: 1584
#          Gradient evaluations: 99
# Optimization terminated successfully.
#          Current function value: -1.280655
#          Iterations: 315
#          Function evaluations: 12640
#          Gradient evaluations: 790
# Optimization terminated successfully.
#          Current function value: -1.280732
#          Iterations: 167
#          Function evaluations: 6160
#          Gradient evaluations: 385
# Optimization terminated successfully.
#          Current function value: -1.280746
#          Iterations: 141
#          Function evaluations: 4768
#          Gradient evaluations: 298
# Optimization terminated successfully.
#          Current function value: -0.809012
#          Iterations: 75
#          Function evaluations: 2736
#          Gradient evaluations: 171
# Optimization terminated successfully.
#          Current function value: -0.999939
#          Iterations: 5
#          Function evaluations: 320
#          Gradient evaluations: 20
# Optimization terminated successfully.
#          Current function value: -1.186114
#          Iterations: 93
#          Function evaluations: 2816
#          Gradient evaluations: 176
# Optimization terminated successfully.
#          Current function value: -1.280736
#          Iterations: 148
#          Function evaluations: 5216
#          Gradient evaluations: 326
# Optimization terminated successfully.
#          Current function value: -0.999980
#          Iterations: 8
#          Function evaluations: 512
#          Gradient evaluations: 32
# Optimization terminated successfully.
#          Current function value: -1.280710
#          Iterations: 170
#          Function evaluations: 7392
#          Gradient evaluations: 462
# Optimization terminated successfully.
#          Current function value: -0.999910
#          Iterations: 9
#          Function evaluations: 448
#          Gradient evaluations: 28
# Optimization terminated successfully.
#          Current function value: -1.280742
#          Iterations: 184
#          Function evaluations: 6496
#          Gradient evaluations: 406
# Optimization terminated successfully.
#          Current function value: -1.280734
#          Iterations: 134
#          Function evaluations: 4576
#          Gradient evaluations: 286
# Optimization terminated successfully.
#          Current function value: -0.499994
#          Iterations: 4
#          Function evaluations: 224
#          Gradient evaluations: 14
# Optimization terminated successfully.
#          Current function value: -1.280734
#          Iterations: 137
#          Function evaluations: 4976
#          Gradient evaluations: 311
# Optimization terminated successfully.
#          Current function value: -1.172290
#          Iterations: 135
#          Function evaluations: 4800
#          Gradient evaluations: 300
# Optimization terminated successfully.
#          Current function value: -1.280704
#          Iterations: 277
#          Function evaluations: 11264
#          Gradient evaluations: 704
# Optimization terminated successfully.
#          Current function value: -1.280727
#          Iterations: 126
#          Function evaluations: 4624
#          Gradient evaluations: 289
# Optimization terminated successfully.
#          Current function value: -1.280719
#          Iterations: 161
#          Function evaluations: 5776
#          Gradient evaluations: 361
# Optimization terminated successfully.
#          Current function value: -0.999952
#          Iterations: 9
#          Function evaluations: 576
#          Gradient evaluations: 36
# Optimization terminated successfully.
#          Current function value: -1.280651
#          Iterations: 106
#          Function evaluations: 4000
#          Gradient evaluations: 250
# Optimization terminated successfully.
#          Current function value: -0.999895
#          Iterations: 3
#          Function evaluations: 176
#          Gradient evaluations: 11
# Optimization terminated successfully.
#          Current function value: -1.280754
#          Iterations: 167
#          Function evaluations: 5952
#          Gradient evaluations: 372
# Optimization terminated successfully.
#          Current function value: -0.999927
#          Iterations: 6
#          Function evaluations: 368
#          Gradient evaluations: 23
# Optimization terminated successfully.
#          Current function value: -1.280689
#          Iterations: 239
#          Function evaluations: 9056
#          Gradient evaluations: 566
# Optimization terminated successfully.
#          Current function value: -0.809013
#          Iterations: 34
#          Function evaluations: 1680
#          Gradient evaluations: 105
# Optimization terminated successfully.
#          Current function value: -1.280727
#          Iterations: 189
#          Function evaluations: 7872
#          Gradient evaluations: 492
# Optimization terminated successfully.
#          Current function value: -1.280688
#          Iterations: 156
#          Function evaluations: 6288
#          Gradient evaluations: 393
# Optimization terminated successfully.
#          Current function value: -0.999899
#          Iterations: 9
#          Function evaluations: 512
#          Gradient evaluations: 32
# Optimization terminated successfully.
#          Current function value: -0.999920
#          Iterations: 7
#          Function evaluations: 448
#          Gradient evaluations: 28
# Optimization terminated successfully.
#          Current function value: -1.280740
#          Iterations: 193
#          Function evaluations: 6896
#          Gradient evaluations: 431
# Optimization terminated successfully.
#          Current function value: -1.280726
#          Iterations: 135
#          Function evaluations: 5248
#          Gradient evaluations: 328
# Optimization terminated successfully.
#          Current function value: -1.151417
#          Iterations: 53
#          Function evaluations: 2208
#          Gradient evaluations: 138
# Optimization terminated successfully.
#          Current function value: -1.280763
#          Iterations: 200
#          Function evaluations: 7056
#          Gradient evaluations: 441
# Optimization terminated successfully.
#          Current function value: -0.999978
#          Iterations: 8
#          Function evaluations: 544
#          Gradient evaluations: 34
# Optimization terminated successfully.
#          Current function value: -1.280688
#          Iterations: 176
#          Function evaluations: 6560
#          Gradient evaluations: 410
# Optimization terminated successfully.
#          Current function value: -1.280655
#          Iterations: 264
#          Function evaluations: 11408
#          Gradient evaluations: 713
# Optimization terminated successfully.
#          Current function value: -1.280692
#          Iterations: 278
#          Function evaluations: 10880
#          Gradient evaluations: 680
# Optimization terminated successfully.
#          Current function value: -1.151321
#          Iterations: 26
#          Function evaluations: 1200
#          Gradient evaluations: 75
# Optimization terminated successfully.
#          Current function value: -1.280701
#          Iterations: 119
#          Function evaluations: 4912
#          Gradient evaluations: 307
# Optimization terminated successfully.
#          Current function value: -1.151372
#          Iterations: 90
#          Function evaluations: 3696
#          Gradient evaluations: 231
# Optimization terminated successfully.
#          Current function value: -1.280680
#          Iterations: 406
#          Function evaluations: 15984
#          Gradient evaluations: 999
# Optimization terminated successfully.
#          Current function value: -1.280666
#          Iterations: 278
#          Function evaluations: 9776
#          Gradient evaluations: 611
# Optimization terminated successfully.
#          Current function value: -1.172143
#          Iterations: 116
#          Function evaluations: 3824
#          Gradient evaluations: 239
# Optimization terminated successfully.
#          Current function value: -1.280727
#          Iterations: 258
#          Function evaluations: 10256
#          Gradient evaluations: 641
# Optimization terminated successfully.
#          Current function value: -0.999938
#          Iterations: 6
#          Function evaluations: 384
#          Gradient evaluations: 24
# Optimization terminated successfully.
#          Current function value: -1.280687
#          Iterations: 245
#          Function evaluations: 9520
#          Gradient evaluations: 595
# Optimization terminated successfully.
#          Current function value: -0.999969
#          Iterations: 7
#          Function evaluations: 464
#          Gradient evaluations: 29
# Optimization terminated successfully.
#          Current function value: -1.280731
#          Iterations: 146
#          Function evaluations: 5360
#          Gradient evaluations: 335
# Optimization terminated successfully.
#          Current function value: -1.280681
#          Iterations: 234
#          Function evaluations: 8880
#          Gradient evaluations: 555
# Optimization terminated successfully.
#          Current function value: -1.280690
#          Iterations: 224
#          Function evaluations: 7632
#          Gradient evaluations: 477
# Optimization terminated successfully.
#          Current function value: -1.280726
#          Iterations: 109
#          Function evaluations: 4176
#          Gradient evaluations: 261
# Optimization terminated successfully.
#          Current function value: -1.280735
#          Iterations: 243
#          Function evaluations: 9552
#          Gradient evaluations: 597
# Optimization terminated successfully.
#          Current function value: -1.151382
#          Iterations: 34
#          Function evaluations: 1776
#          Gradient evaluations: 111
# Optimization terminated successfully.
#          Current function value: -0.999959
#          Iterations: 8
#          Function evaluations: 496
#          Gradient evaluations: 31
# Optimization terminated successfully.
#          Current function value: -1.280648
#          Iterations: 211
#          Function evaluations: 8610
#          Gradient evaluations: 538
# Optimization terminated successfully.
#          Current function value: -1.280649
#          Iterations: 270
#          Function evaluations: 11424
#          Gradient evaluations: 714
# Optimization terminated successfully.
#          Current function value: -1.280681
#          Iterations: 186
#          Function evaluations: 7456
#          Gradient evaluations: 466
# Optimization terminated successfully.
#          Current function value: -1.280684
#          Iterations: 109
#          Function evaluations: 4144
#          Gradient evaluations: 259
# Optimization terminated successfully.
#          Current function value: -0.999909
#          Iterations: 6
#          Function evaluations: 336
#          Gradient evaluations: 21
# Optimization terminated successfully.
#          Current function value: -1.280665
#          Iterations: 321
#          Function evaluations: 12496
#          Gradient evaluations: 781
# Optimization terminated successfully.
#          Current function value: -1.280734
#          Iterations: 137
#          Function evaluations: 5024
#          Gradient evaluations: 314
# Optimization terminated successfully.
#          Current function value: -1.280695
#          Iterations: 220
#          Function evaluations: 8160
#          Gradient evaluations: 510
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: -1.280661
#          Iterations: 359
#          Function evaluations: 15596
#          Gradient evaluations: 974
# Optimization terminated successfully.
#          Current function value: -0.809050
#          Iterations: 61
#          Function evaluations: 2016
#          Gradient evaluations: 126
# Optimization terminated successfully.
#          Current function value: -1.280687
#          Iterations: 176
#          Function evaluations: 6864
#          Gradient evaluations: 429
# Optimization terminated successfully.
#          Current function value: -1.280754
#          Iterations: 215
#          Function evaluations: 7280
#          Gradient evaluations: 455
# Optimization terminated successfully.
#          Current function value: -0.999922
#          Iterations: 5
#          Function evaluations: 320
#          Gradient evaluations: 20
# Optimization terminated successfully.
#          Current function value: -1.280705
#          Iterations: 211
#          Function evaluations: 8464
#          Gradient evaluations: 529
# Optimization terminated successfully.
#          Current function value: -1.280746
#          Iterations: 277
#          Function evaluations: 11776
#          Gradient evaluations: 736
# Optimization terminated successfully.
#          Current function value: -1.280711
#          Iterations: 200
#          Function evaluations: 7696
#          Gradient evaluations: 481
# Optimization terminated successfully.
#          Current function value: -0.999955
#          Iterations: 5
#          Function evaluations: 304
#          Gradient evaluations: 19
# Optimization terminated successfully.
#          Current function value: -1.280659
#          Iterations: 407
#          Function evaluations: 16144
#          Gradient evaluations: 1009
# Optimization terminated successfully.
#          Current function value: -1.280672
#          Iterations: 167
#          Function evaluations: 6816
#          Gradient evaluations: 426
# Optimization terminated successfully.
#          Current function value: -0.999968
#          Iterations: 8
#          Function evaluations: 464
#          Gradient evaluations: 29
# Optimization terminated successfully.
#          Current function value: -0.999978
#          Iterations: 4
#          Function evaluations: 224
#          Gradient evaluations: 14
# Optimization terminated successfully.
#          Current function value: -1.280669
#          Iterations: 207
#          Function evaluations: 7872
#          Gradient evaluations: 492
# Optimization terminated successfully.
#          Current function value: -1.280662
#          Iterations: 236
#          Function evaluations: 9888
#          Gradient evaluations: 618
# Optimization terminated successfully.
#          Current function value: -1.151376
#          Iterations: 151
#          Function evaluations: 4912
#          Gradient evaluations: 307

# %%
plt.figure(figsize=(10,10))
ttl = plt.suptitle("N = 3, M = 1 \n Wavefunction Error Histogram",size =20)
ttl.set_position([.5, 0.95])
plt.hist(N3M1stateErr, bins=50) 
plt.xlabel("Wavefunction Error",size = 15)
plt.ylabel("Frequency", size = 15)
plt.show()

# %%
plt.figure(figsize=(10,10))
ttl = plt.suptitle("N = 3, M = 1 \n Runtime Histogram",size =20)
ttl.set_position([.5, 0.95])
plt.hist(N3M1gdTime, bins=100) 
plt.xlabel("Runtime",size = 15)
plt.ylabel("Frequency", size = 15)
plt.show()

# %%
plt.figure(figsize=(10,10))
ttl = plt.suptitle("N = 3, M = 1 ",size =20)
ttl.set_position([.5, 0.92])
ax1 = plt.subplot(2,1,1)

color = 'tab:red'
ax1.set_xlabel('N Value')
ax1.set_ylabel('Wavefunction Error', color=color)
ax1.scatter(hisIt, N3M1stateErr,color=color)
ax1.tick_params(axis='y', labelcolor=color)

ax2 = ax1.twinx()  

color = 'tab:blue'
ax2.set_ylabel('Runtime', color=color)  
ax2.scatter(hisIt, N3M1gdTime, color=color)
ax2.tick_params(axis='y', labelcolor=color)
